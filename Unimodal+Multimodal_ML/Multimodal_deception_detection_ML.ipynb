# %% [markdown]
# ## A Machine Learning Approach to combine all three modalities i.e. Audio, Micro-Expression and Gaze
#
# Audio, gaze and Microexpression is combined using a Classifier and importance for each modality is plotted

# %%
import sys
sys.path.append('/home/adrikamukherjee/venv/lib/python3.6/site-packages')

# %%
#import necessary packages
import os, sys, glob, csv, numpy as np, pandas as pd, matplotlib.pyplot as plt, tensorflow as tf, IPython.display as ipd, keras
from sklearn import model_selection, preprocessing
from os import walk, path
from tensorflow.keras import models, layers, optimizers, preprocessing as KRSpreps, utils as KRSutils
import xgboost as xgb
from tensorflow.keras import utils as np_utils
import re
from sklearn import metrics
import matplotlib.pyplot as plt
import glob
import datetime
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Create Dictionary and store paths for all different Modalities(Audio, Micro-expression and Gaze)

# %%
data_path = {}
data_path['audiodata_path'] = "/home/adrikamukherjee/Audio_Features/csv_full_audio"
data_path['gazedata_path'] = "/home/adrikamukherjee/Gaze_Features"
data_path['mexpdata_path'] = "/home/adrikamukherjee/Mexp_Features"

# %% [markdown]
# ### Checking No. of files in each of Audio, Micro-expression & Gaze Folders && Shape of the Dataframes

# %%
c_gaze=0
c_mexp=0
c_audio=0
for gazefilepath in glob.glob(os.path.join(data_path['audiodata_path'], '*.csv')):
    c_gaze +=1
for audiofilepath in glob.glob(os.path.join(data_path['gazedata_path'], '*.csv')):
    c_audio +=1
for mexpdatapath in glob.glob(os.path.join(data_path['mexpdata_path'], '*.csv')):
    c_mexp +=1
    
print("Number of Gaze Data : " + str(c_gaze))
print("Number of Audio Data : " + str(c_audio))
print("Number of Mexp Data : " + str(c_mexp))
# Out:
# Number of Gaze Data : 657
# Number of Audio Data : 657
# Number of Mexp Data : 657

# %% [markdown]
# ## Creating Dictionaries of Audio, Micro-expression & Gaze
# Remove Initials and Make the Keys Same for the Same data

# %%
from glob import glob

# %%
data_shape_all = pd.DataFrame()
for key in data_path.keys():
    count = 0
    data_shape, file_names = [], []
    for filepath in glob(os.path.join(data_path[key], '*.csv')):
        file_shape = pd.read_csv(filepath).shape
        data_shape.append([file_shape[0], file_shape[1]])
        filename = path.basename(filepath)
        for reps in (("Gaze_", ""), ("Audio_", ""), ("Mexp_", "")):
            filename = filename.replace(*reps)
        file_names.append(filename)
        count+=1
    data_shape = pd.DataFrame(data_shape)
    data_shape.columns = [key + str(0), key +str(1)]
    data_shape.index = pd.Series(file_names)
    data_shape_all = pd.concat([data_shape_all, data_shape], axis = 1)
    print(f"No. of file in {key}: ", count)
data_shape_all
# Out:
# No. of file in audiodata_path:  657
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   app.launch_new_instance()
# No. of file in gazedata_path:  657
# No. of file in mexpdata_path:  657
#                                        audiodata_path0  audiodata_path1  \
# BagOfLies_User_0_run_0_video.csv                     1              992
# BagOfLies_User_0_run_1_video.csv                     1              992
# BagOfLies_User_0_run_2_video.csv                     1              992
# BagOfLies_User_0_run_3_video.csv                     1              992
# BagOfLies_User_0_run_4_video.csv                     1              992
# BagOfLies_User_0_run_5_video.csv                     1              992
# BagOfLies_User_10_run_0_video.csv                    1              992
# BagOfLies_User_10_run_1_video.csv                    1              992
# BagOfLies_User_10_run_2_video.csv                    1              992
# BagOfLies_User_10_run_3_video.csv                    1              992
# BagOfLies_User_10_run_4_video.csv                    1              992
# BagOfLies_User_10_run_5_video.csv                    1              992
# BagOfLies_User_10_run_6_video.csv                    1              992
# BagOfLies_User_10_run_7_video.csv                    1              992
# BagOfLies_User_10_run_8_video.csv                    1              992
# BagOfLies_User_11_run_0_video.csv                    1              992
# BagOfLies_User_11_run_1_video.csv                    1              992
# BagOfLies_User_11_run_2_video.csv                    1              992
# BagOfLies_User_11_run_3_video.csv                    1              992
# BagOfLies_User_11_run_4_video.csv                    1              992
# BagOfLies_User_11_run_5_video.csv                    1              992
# BagOfLies_User_11_run_6_video.csv                    1              992
# BagOfLies_User_11_run_7_video.csv                    1              992
# BagOfLies_User_11_run_8_video.csv                    1              992
# BagOfLies_User_11_run_9_video.csv                    1              992
# BagOfLies_User_12_run_0_video.csv                    1              992
# BagOfLies_User_12_run_1_video.csv                    1              992
# BagOfLies_User_12_run_2_video.csv                    1              992
# BagOfLies_User_12_run_3_video.csv                    1              992
# BagOfLies_User_12_run_4_video.csv                    1              992
# ...                                                ...              ...
# reallifedeception_trial_truth_031.csv                1              992
# reallifedeception_trial_truth_032.csv                1              992
# reallifedeception_trial_truth_033.csv                1              992
# reallifedeception_trial_truth_034.csv                1              992
# reallifedeception_trial_truth_035.csv                1              992
# reallifedeception_trial_truth_036.csv                1              992
# reallifedeception_trial_truth_037.csv                1              992
# reallifedeception_trial_truth_038.csv                1              992
# reallifedeception_trial_truth_039.csv                1              992
# reallifedeception_trial_truth_040.csv                1              992
# reallifedeception_trial_truth_041.csv                1              992
# reallifedeception_trial_truth_042.csv                1              992
# reallifedeception_trial_truth_043.csv                1              992
# reallifedeception_trial_truth_044.csv                1              992
# reallifedeception_trial_truth_045.csv                1              992
# reallifedeception_trial_truth_046.csv                1              992
# reallifedeception_trial_truth_047.csv                1              992
# reallifedeception_trial_truth_048.csv                1              992
# reallifedeception_trial_truth_049.csv                1              992
# reallifedeception_trial_truth_050.csv                1              992
# reallifedeception_trial_truth_051.csv                1              992
# reallifedeception_trial_truth_052.csv                1              992
# reallifedeception_trial_truth_053.csv                1              992
# reallifedeception_trial_truth_054.csv                1              992
# reallifedeception_trial_truth_055.csv                1              992
# reallifedeception_trial_truth_056.csv                1              992
# reallifedeception_trial_truth_057.csv                1              992
# reallifedeception_trial_truth_058.csv                1              992
# reallifedeception_trial_truth_059.csv                1              992
# reallifedeception_trial_truth_060.csv                1              992
#
#                                        gazedata_path0  gazedata_path1  \
# BagOfLies_User_0_run_0_video.csv                  245             295
# BagOfLies_User_0_run_1_video.csv                  211             295
# BagOfLies_User_0_run_2_video.csv                  231             295
# BagOfLies_User_0_run_3_video.csv                  210             295
# BagOfLies_User_0_run_4_video.csv                  167             295
# BagOfLies_User_0_run_5_video.csv                  220             295
# BagOfLies_User_10_run_0_video.csv                 187             295
# BagOfLies_User_10_run_1_video.csv                 211             295
# BagOfLies_User_10_run_2_video.csv                 245             295
# BagOfLies_User_10_run_3_video.csv                 263             295
# BagOfLies_User_10_run_4_video.csv                 268             295
# BagOfLies_User_10_run_5_video.csv                 253             295
# BagOfLies_User_10_run_6_video.csv                 248             295
# BagOfLies_User_10_run_7_video.csv                 217             295
# BagOfLies_User_10_run_8_video.csv                 149             295
# BagOfLies_User_11_run_0_video.csv                 188             295
# BagOfLies_User_11_run_1_video.csv                 214             295
# BagOfLies_User_11_run_2_video.csv                 242             295
# BagOfLies_User_11_run_3_video.csv                 279             295
# BagOfLies_User_11_run_4_video.csv                 232             295
# BagOfLies_User_11_run_5_video.csv                 195             295
# BagOfLies_User_11_run_6_video.csv                 214             295
# BagOfLies_User_11_run_7_video.csv                 235             295
# BagOfLies_User_11_run_8_video.csv                 274             295
# BagOfLies_User_11_run_9_video.csv                 172             295
# BagOfLies_User_12_run_0_video.csv                 190             295
# BagOfLies_User_12_run_1_video.csv                 254             295
# BagOfLies_User_12_run_2_video.csv                 232             295
# BagOfLies_User_12_run_3_video.csv                 165             295
# BagOfLies_User_12_run_4_video.csv                 174             295
# ...                                               ...             ...
# reallifedeception_trial_truth_031.csv             450             295
# reallifedeception_trial_truth_032.csv             925             295
# reallifedeception_trial_truth_033.csv             425             295
# reallifedeception_trial_truth_034.csv             775             295
# reallifedeception_trial_truth_035.csv             750             295
# reallifedeception_trial_truth_036.csv             925             295
# reallifedeception_trial_truth_037.csv             549             295
# reallifedeception_trial_truth_038.csv             474             295
# reallifedeception_trial_truth_039.csv             800             295
# reallifedeception_trial_truth_040.csv             774             295
# reallifedeception_trial_truth_041.csv             340             295
# reallifedeception_trial_truth_042.csv             300             295
# reallifedeception_trial_truth_043.csv             220             295
# reallifedeception_trial_truth_044.csv             210             295
# reallifedeception_trial_truth_045.csv             330             295
# reallifedeception_trial_truth_046.csv             370             295
# reallifedeception_trial_truth_047.csv             260             295
# reallifedeception_trial_truth_048.csv             260             295
# reallifedeception_trial_truth_049.csv             300             295
# reallifedeception_trial_truth_050.csv             230             295
# reallifedeception_trial_truth_051.csv             870             295
# reallifedeception_trial_truth_052.csv             290             295
# reallifedeception_trial_truth_053.csv             810             295
# reallifedeception_trial_truth_054.csv             720             295
# reallifedeception_trial_truth_055.csv             870             295
# reallifedeception_trial_truth_056.csv            1019             295
# reallifedeception_trial_truth_057.csv            1139             295
# reallifedeception_trial_truth_058.csv             630             295
# reallifedeception_trial_truth_059.csv             810             295
# reallifedeception_trial_truth_060.csv             540             295
#
#                                        mexpdata_path0  mexpdata_path1
# BagOfLies_User_0_run_0_video.csv                  245              48
# BagOfLies_User_0_run_1_video.csv                  211              48
# BagOfLies_User_0_run_2_video.csv                  231              48
# BagOfLies_User_0_run_3_video.csv                  210              48
# BagOfLies_User_0_run_4_video.csv                  167              48
# BagOfLies_User_0_run_5_video.csv                  220              48
# BagOfLies_User_10_run_0_video.csv                 187              48
# BagOfLies_User_10_run_1_video.csv                 211              48
# BagOfLies_User_10_run_2_video.csv                 245              48
# BagOfLies_User_10_run_3_video.csv                 263              48
# BagOfLies_User_10_run_4_video.csv                 268              48
# BagOfLies_User_10_run_5_video.csv                 253              48
# BagOfLies_User_10_run_6_video.csv                 248              48
# BagOfLies_User_10_run_7_video.csv                 217              48
# BagOfLies_User_10_run_8_video.csv                 149              48
# BagOfLies_User_11_run_0_video.csv                 188              48
# BagOfLies_User_11_run_1_video.csv                 214              48
# BagOfLies_User_11_run_2_video.csv                 242              48
# BagOfLies_User_11_run_3_video.csv                 279              48
# BagOfLies_User_11_run_4_video.csv                 232              48
# BagOfLies_User_11_run_5_video.csv                 195              48
# BagOfLies_User_11_run_6_video.csv                 214              48
# BagOfLies_User_11_run_7_video.csv                 235              48
# BagOfLies_User_11_run_8_video.csv                 274              48
# BagOfLies_User_11_run_9_video.csv                 172              48
# BagOfLies_User_12_run_0_video.csv                 190              48
# BagOfLies_User_12_run_1_video.csv                 254              48
# BagOfLies_User_12_run_2_video.csv                 232              48
# BagOfLies_User_12_run_3_video.csv                 165              48
# BagOfLies_User_12_run_4_video.csv                 174              48
# ...                                               ...             ...
# reallifedeception_trial_truth_031.csv             450              48
# reallifedeception_trial_truth_032.csv             925              48
# reallifedeception_trial_truth_033.csv             425              48
# reallifedeception_trial_truth_034.csv             775              48
# reallifedeception_trial_truth_035.csv             750              48
# reallifedeception_trial_truth_036.csv             925              48
# reallifedeception_trial_truth_037.csv             549              48
# reallifedeception_trial_truth_038.csv             474              48
# reallifedeception_trial_truth_039.csv             800              48
# reallifedeception_trial_truth_040.csv             774              48
# reallifedeception_trial_truth_041.csv             340              48
# reallifedeception_trial_truth_042.csv             300              48
# reallifedeception_trial_truth_043.csv             220              48
# reallifedeception_trial_truth_044.csv             210              48
# reallifedeception_trial_truth_045.csv             330              48
# reallifedeception_trial_truth_046.csv             370              48
# reallifedeception_trial_truth_047.csv             260              48
# reallifedeception_trial_truth_048.csv             260              48
# reallifedeception_trial_truth_049.csv             300              48
# reallifedeception_trial_truth_050.csv             230              48
# reallifedeception_trial_truth_051.csv             870              48
# reallifedeception_trial_truth_052.csv             290              48
# reallifedeception_trial_truth_053.csv             810              48
# reallifedeception_trial_truth_054.csv             720              48
# reallifedeception_trial_truth_055.csv             870              48
# reallifedeception_trial_truth_056.csv            1019              48
# reallifedeception_trial_truth_057.csv            1139              48
# reallifedeception_trial_truth_058.csv             630              48
# reallifedeception_trial_truth_059.csv             810              48
# reallifedeception_trial_truth_060.csv             540              48
#
# [657 rows x 6 columns]

# %%
audio_dict, gaze_dict, mexp_dict = {}, {}, {}
listofdicts = [audio_dict, gaze_dict, mexp_dict]
for key, data_dict_indiv in zip(data_path.keys(), listofdicts):
    for filepath in glob(path.join(data_path[key], '*.csv')):
        data = pd.read_csv(filepath)
        filename = path.basename(filepath)
        for reps in (("Gaze_", ""), ("Audio_", ""), ("Mexp_", "")):
            filename = filename.replace(*reps)
        data_dict_indiv[filename] = data

# %% [markdown]
# ### Checking If the Labels are Same for Same Keys in Each Dcitionaries & Separating Labels from Training Data

# %%
filename_dictkeys = list(audio_dict)
label_dict = {}
for key in filename_dictkeys:
    audiodata, gazedata, mexpdata = audio_dict[key], gaze_dict[key], mexp_dict[key]
    label_audio = audiodata.loc[:, "label"].unique()[0]
    label_gaze = gazedata.loc[:, "label"].unique()[0]
    label_mexp = mexpdata.loc[:, "label"].unique()[0]
    label_set = set([label_audio, label_gaze, label_mexp])
    if len(label_set) > 1:
        print(key)
    else:
        label_dict[key] = list(label_set)[0]

# %% [markdown]
# ### Encode labels and store it in a dictionary with the universal keys that holds all the data

# %%
label_to_num = lambda value: 0 if value == 'Truthful' else 1
label_dict_num = {key: label_to_num(value) for key, value in label_dict.items()}
label_dict_num

# %% [markdown]
# ### Mean vector for all the modalities is calculated
#
# frame wise data is replaced by single row which can be efficiently handled by Machine Learning Models

# %%
df_list_mexp, df_list_audio, df_list_gaze,df_label  = [], [], [], []
for key in filename_dictkeys:
    audio_dict[key].drop(["name", "frameTime", "Unnamed: 0", "label"], axis = 1, inplace = True)
    audio_dict[key]=audio_dict[key].mean(axis=0)
    gaze_dict[key].drop(["frame", "Unnamed: 0", "label"], axis = 1, inplace = True)
    gaze_dict[key]=gaze_dict[key].mean(axis=0)
    mexp_dict[key].drop(["frame", "Unnamed: 0", "label"], axis = 1, inplace = True)
    mexp_dict[key]=mexp_dict[key].mean(axis=0)
    mexp_individual=mexp_dict[key].to_numpy()
    audio_individual=audio_dict[key].to_numpy()
    gaze_individual=gaze_dict[key].to_numpy()
    label_individual=label_dict_num[key]
    df_list_mexp.append(mexp_individual)
    df_list_audio.append(audio_individual)
    df_list_gaze.append(gaze_individual)
    df_label.append(label_individual)

# %% [markdown]
# ### Convert Dataframe to numpy arrays

# %%
df_list_mexp=np.asarray(df_list_mexp)
df_list_mexp.shape
df_list_audio=np.asarray(df_list_audio)
df_list_audio.shape
df_list_gaze=np.asarray(df_list_gaze)
df_list_gaze.shape
# Out:
# (657, 292)

# %% [markdown]
# ### Split train and test data && check if the labels are aligned

# %%
split1 = train_test_split(df_list_mexp, df_label, test_size=0.1, random_state=42)
split2=  train_test_split(df_list_audio, df_label, test_size=0.1, random_state=42)
split3 = train_test_split(df_list_gaze, df_label, test_size=0.1, random_state=42)
(X_train_m, X_test_m, y_train_m, y_test_m) = split1
(X_train_a, X_test_a, y_train_a, y_test_a) = split2
(X_train_g, X_test_g, y_train_g, y_test_g) = split3

print(np.all(y_test_m == y_test_a))
print(np.all(y_test_a == y_test_g))
# Out:
# True
# True

# %% [markdown]
# ### XGboost is applied on the Audio data

# %%
from xgboost.sklearn import XGBClassifier
model_a = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=3, 
                      gamma=10)
eval_set = [(X_train_a, y_train_a), (X_test_a, y_test_a)]
model_a.fit(X_train_a, y_train_a, early_stopping_rounds=10, eval_metric=["error", "logloss"], eval_set=eval_set,verbose=True)
# make predictions for test data
y_pred = model_a.predict(X_test_a)
predictions_audio_test = [round(value) for value in y_pred]
# evaluate predictions
accuracy = metrics.accuracy_score(y_test_a, predictions_audio_test)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# retrieve performance metrics
results = model_a.evals_result()
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# plot classification error
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Test')
ax.legend()
plt.ylabel('Classification Error')
plt.title('XGBoost Classification Error')
plt.show()
# Out:
# [0]	validation_0-error:0.333333	validation_0-logloss:0.691625	validation_1-error:0.439394	validation_1-logloss:0.692075
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-error:0.321489	validation_0-logloss:0.689954	validation_1-error:0.424242	validation_1-logloss:0.691404
# [2]	validation_0-error:0.296108	validation_0-logloss:0.688064	validation_1-error:0.409091	validation_1-logloss:0.690501
# [3]	validation_0-error:0.299492	validation_0-logloss:0.686526	validation_1-error:0.454545	validation_1-logloss:0.690325
# [4]	validation_0-error:0.277496	validation_0-logloss:0.684633	validation_1-error:0.439394	validation_1-logloss:0.689417
# [5]	validation_0-error:0.285956	validation_0-logloss:0.682897	validation_1-error:0.424242	validation_1-logloss:0.688168
# [6]	validation_0-error:0.284264	validation_0-logloss:0.681197	validation_1-error:0.424242	validation_1-logloss:0.687221
# [7]	validation_0-error:0.28088	validation_0-logloss:0.679772	validation_1-error:0.393939	validation_1-logloss:0.68574
# [8]	validation_0-error:0.279188	validation_0-logloss:0.678329	validation_1-error:0.378788	validation_1-logloss:0.684865
# [9]	validation_0-error:0.279188	validation_0-logloss:0.67677	validation_1-error:0.378788	validation_1-logloss:0.68443
# [10]	validation_0-error:0.279188	validation_0-logloss:0.675098	validation_1-error:0.393939	validation_1-logloss:0.683582
# [11]	validation_0-error:0.263959	validation_0-logloss:0.67328	validation_1-error:0.393939	validation_1-logloss:0.682591
# [12]	validation_0-error:0.252115	validation_0-logloss:0.671847	validation_1-error:0.393939	validation_1-logloss:0.682812
# [13]	validation_0-error:0.279188	validation_0-logloss:0.670404	validation_1-error:0.424242	validation_1-logloss:0.683682
# [14]	validation_0-error:0.274112	validation_0-logloss:0.669131	validation_1-error:0.393939	validation_1-logloss:0.682834
# [15]	validation_0-error:0.247039	validation_0-logloss:0.667294	validation_1-error:0.378788	validation_1-logloss:0.68219
# [16]	validation_0-error:0.263959	validation_0-logloss:0.666098	validation_1-error:0.363636	validation_1-logloss:0.681341
# [17]	validation_0-error:0.258883	validation_0-logloss:0.664408	validation_1-error:0.409091	validation_1-logloss:0.680471
# [18]	validation_0-error:0.262267	validation_0-logloss:0.663314	validation_1-error:0.393939	validation_1-logloss:0.67956
# [19]	validation_0-error:0.265651	validation_0-logloss:0.662243	validation_1-error:0.393939	validation_1-logloss:0.679289
# [20]	validation_0-error:0.270728	validation_0-logloss:0.661005	validation_1-error:0.393939	validation_1-logloss:0.678429
# [21]	validation_0-error:0.27242	validation_0-logloss:0.659664	validation_1-error:0.363636	validation_1-logloss:0.677868
# [22]	validation_0-error:0.270728	validation_0-logloss:0.658378	validation_1-error:0.393939	validation_1-logloss:0.677004
# [23]	validation_0-error:0.270728	validation_0-logloss:0.65664	validation_1-error:0.378788	validation_1-logloss:0.675627
# [24]	validation_0-error:0.267343	validation_0-logloss:0.655212	validation_1-error:0.378788	validation_1-logloss:0.674798
# [25]	validation_0-error:0.262267	validation_0-logloss:0.653629	validation_1-error:0.378788	validation_1-logloss:0.674139
# [26]	validation_0-error:0.258883	validation_0-logloss:0.65207	validation_1-error:0.378788	validation_1-logloss:0.673072
# [27]	validation_0-error:0.258883	validation_0-logloss:0.650933	validation_1-error:0.378788	validation_1-logloss:0.673187
# [28]	validation_0-error:0.260575	validation_0-logloss:0.649669	validation_1-error:0.333333	validation_1-logloss:0.672053
# [29]	validation_0-error:0.265651	validation_0-logloss:0.648762	validation_1-error:0.363636	validation_1-logloss:0.671727
# [30]	validation_0-error:0.260575	validation_0-logloss:0.64743	validation_1-error:0.348485	validation_1-logloss:0.670822
# [31]	validation_0-error:0.257191	validation_0-logloss:0.646218	validation_1-error:0.348485	validation_1-logloss:0.669961
# [32]	validation_0-error:0.247039	validation_0-logloss:0.644987	validation_1-error:0.348485	validation_1-logloss:0.669992
# [33]	validation_0-error:0.252115	validation_0-logloss:0.643475	validation_1-error:0.363636	validation_1-logloss:0.668508
# [34]	validation_0-error:0.243655	validation_0-logloss:0.64242	validation_1-error:0.348485	validation_1-logloss:0.667772
# [35]	validation_0-error:0.250423	validation_0-logloss:0.641122	validation_1-error:0.363636	validation_1-logloss:0.66711
# [36]	validation_0-error:0.255499	validation_0-logloss:0.640168	validation_1-error:0.378788	validation_1-logloss:0.666684
# [37]	validation_0-error:0.252115	validation_0-logloss:0.638803	validation_1-error:0.363636	validation_1-logloss:0.665653
# [38]	validation_0-error:0.241963	validation_0-logloss:0.637537	validation_1-error:0.378788	validation_1-logloss:0.665533
# [39]	validation_0-error:0.243655	validation_0-logloss:0.636149	validation_1-error:0.363636	validation_1-logloss:0.665059
# [40]	validation_0-error:0.245347	validation_0-logloss:0.635266	validation_1-error:0.348485	validation_1-logloss:0.664103
# [41]	validation_0-error:0.245347	validation_0-logloss:0.634133	validation_1-error:0.378788	validation_1-logloss:0.663611
# [42]	validation_0-error:0.245347	validation_0-logloss:0.632823	validation_1-error:0.378788	validation_1-logloss:0.663379
# [43]	validation_0-error:0.250423	validation_0-logloss:0.63171	validation_1-error:0.378788	validation_1-logloss:0.663089
# [44]	validation_0-error:0.245347	validation_0-logloss:0.630911	validation_1-error:0.378788	validation_1-logloss:0.662388
# [45]	validation_0-error:0.236887	validation_0-logloss:0.629897	validation_1-error:0.378788	validation_1-logloss:0.662093
# [46]	validation_0-error:0.236887	validation_0-logloss:0.628792	validation_1-error:0.378788	validation_1-logloss:0.661149
# [47]	validation_0-error:0.240271	validation_0-logloss:0.627615	validation_1-error:0.378788	validation_1-logloss:0.660751
# [48]	validation_0-error:0.230118	validation_0-logloss:0.626858	validation_1-error:0.363636	validation_1-logloss:0.660754
# [49]	validation_0-error:0.236887	validation_0-logloss:0.625879	validation_1-error:0.363636	validation_1-logloss:0.660208
# [50]	validation_0-error:0.236887	validation_0-logloss:0.625143	validation_1-error:0.363636	validation_1-logloss:0.659766
# [51]	validation_0-error:0.233503	validation_0-logloss:0.624061	validation_1-error:0.363636	validation_1-logloss:0.659372
# [52]	validation_0-error:0.236887	validation_0-logloss:0.623125	validation_1-error:0.363636	validation_1-logloss:0.658209
# [53]	validation_0-error:0.233503	validation_0-logloss:0.622061	validation_1-error:0.378788	validation_1-logloss:0.657997
# [54]	validation_0-error:0.233503	validation_0-logloss:0.62102	validation_1-error:0.378788	validation_1-logloss:0.657728
# [55]	validation_0-error:0.221658	validation_0-logloss:0.619877	validation_1-error:0.363636	validation_1-logloss:0.65747
# [56]	validation_0-error:0.230118	validation_0-logloss:0.619095	validation_1-error:0.348485	validation_1-logloss:0.657615
# [57]	validation_0-error:0.23181	validation_0-logloss:0.617864	validation_1-error:0.378788	validation_1-logloss:0.657199
# [58]	validation_0-error:0.228426	validation_0-logloss:0.617063	validation_1-error:0.348485	validation_1-logloss:0.656704
# [59]	validation_0-error:0.226734	validation_0-logloss:0.616365	validation_1-error:0.333333	validation_1-logloss:0.655976
# [60]	validation_0-error:0.228426	validation_0-logloss:0.615619	validation_1-error:0.378788	validation_1-logloss:0.655782
# [61]	validation_0-error:0.225042	validation_0-logloss:0.614932	validation_1-error:0.348485	validation_1-logloss:0.655504
# [62]	validation_0-error:0.221658	validation_0-logloss:0.614167	validation_1-error:0.378788	validation_1-logloss:0.655254
# [63]	validation_0-error:0.221658	validation_0-logloss:0.613359	validation_1-error:0.378788	validation_1-logloss:0.655016
# [64]	validation_0-error:0.225042	validation_0-logloss:0.612691	validation_1-error:0.393939	validation_1-logloss:0.655172
# [65]	validation_0-error:0.22335	validation_0-logloss:0.612033	validation_1-error:0.393939	validation_1-logloss:0.654487
# [66]	validation_0-error:0.221658	validation_0-logloss:0.610983	validation_1-error:0.378788	validation_1-logloss:0.654007
# [67]	validation_0-error:0.221658	validation_0-logloss:0.61021	validation_1-error:0.378788	validation_1-logloss:0.653954
# [68]	validation_0-error:0.218274	validation_0-logloss:0.609237	validation_1-error:0.378788	validation_1-logloss:0.653753
# [69]	validation_0-error:0.221658	validation_0-logloss:0.60826	validation_1-error:0.378788	validation_1-logloss:0.653712
# [70]	validation_0-error:0.221658	validation_0-logloss:0.607743	validation_1-error:0.378788	validation_1-logloss:0.653173
# [71]	validation_0-error:0.221658	validation_0-logloss:0.606312	validation_1-error:0.378788	validation_1-logloss:0.652392
# [72]	validation_0-error:0.221658	validation_0-logloss:0.605607	validation_1-error:0.378788	validation_1-logloss:0.65244
# [73]	validation_0-error:0.221658	validation_0-logloss:0.604534	validation_1-error:0.378788	validation_1-logloss:0.65234
# [74]	validation_0-error:0.219966	validation_0-logloss:0.603612	validation_1-error:0.378788	validation_1-logloss:0.651757
# [75]	validation_0-error:0.226734	validation_0-logloss:0.602605	validation_1-error:0.378788	validation_1-logloss:0.65119
# [76]	validation_0-error:0.22335	validation_0-logloss:0.601834	validation_1-error:0.378788	validation_1-logloss:0.651325
# [77]	validation_0-error:0.230118	validation_0-logloss:0.60105	validation_1-error:0.378788	validation_1-logloss:0.651172
# [78]	validation_0-error:0.225042	validation_0-logloss:0.60007	validation_1-error:0.363636	validation_1-logloss:0.651022
# [79]	validation_0-error:0.225042	validation_0-logloss:0.599097	validation_1-error:0.378788	validation_1-logloss:0.651708
# [80]	validation_0-error:0.22335	validation_0-logloss:0.598422	validation_1-error:0.378788	validation_1-logloss:0.651179
# [81]	validation_0-error:0.22335	validation_0-logloss:0.597635	validation_1-error:0.363636	validation_1-logloss:0.650434
# [82]	validation_0-error:0.221658	validation_0-logloss:0.596802	validation_1-error:0.363636	validation_1-logloss:0.650282
# [83]	validation_0-error:0.226734	validation_0-logloss:0.596118	validation_1-error:0.363636	validation_1-logloss:0.649974
# [84]	validation_0-error:0.225042	validation_0-logloss:0.595146	validation_1-error:0.363636	validation_1-logloss:0.649145
# [85]	validation_0-error:0.22335	validation_0-logloss:0.594072	validation_1-error:0.348485	validation_1-logloss:0.648973
# [86]	validation_0-error:0.221658	validation_0-logloss:0.593666	validation_1-error:0.348485	validation_1-logloss:0.648411
# [87]	validation_0-error:0.219966	validation_0-logloss:0.593231	validation_1-error:0.363636	validation_1-logloss:0.649183
# [88]	validation_0-error:0.221658	validation_0-logloss:0.592548	validation_1-error:0.363636	validation_1-logloss:0.648811
# [89]	validation_0-error:0.221658	validation_0-logloss:0.591653	validation_1-error:0.348485	validation_1-logloss:0.648048
# [90]	validation_0-error:0.218274	validation_0-logloss:0.590972	validation_1-error:0.363636	validation_1-logloss:0.647588
# [91]	validation_0-error:0.221658	validation_0-logloss:0.59031	validation_1-error:0.363636	validation_1-logloss:0.647758
# [92]	validation_0-error:0.216582	validation_0-logloss:0.589647	validation_1-error:0.348485	validation_1-logloss:0.647058
# [93]	validation_0-error:0.218274	validation_0-logloss:0.588818	validation_1-error:0.348485	validation_1-logloss:0.647052
# [94]	validation_0-error:0.216582	validation_0-logloss:0.587856	validation_1-error:0.378788	validation_1-logloss:0.646658
# [95]	validation_0-error:0.21489	validation_0-logloss:0.587188	validation_1-error:0.378788	validation_1-logloss:0.646485
# [96]	validation_0-error:0.21489	validation_0-logloss:0.58591	validation_1-error:0.363636	validation_1-logloss:0.645087
# [97]	validation_0-error:0.21489	validation_0-logloss:0.585502	validation_1-error:0.363636	validation_1-logloss:0.644577
# [98]	validation_0-error:0.21489	validation_0-logloss:0.584741	validation_1-error:0.363636	validation_1-logloss:0.644498
# [99]	validation_0-error:0.216582	validation_0-logloss:0.584399	validation_1-error:0.363636	validation_1-logloss:0.644165
# [100]	validation_0-error:0.21489	validation_0-logloss:0.583861	validation_1-error:0.378788	validation_1-logloss:0.643943
# [101]	validation_0-error:0.21489	validation_0-logloss:0.583403	validation_1-error:0.348485	validation_1-logloss:0.643247
# [102]	validation_0-error:0.216582	validation_0-logloss:0.582457	validation_1-error:0.378788	validation_1-logloss:0.642751
# [103]	validation_0-error:0.218274	validation_0-logloss:0.582042	validation_1-error:0.363636	validation_1-logloss:0.642571
# [104]	validation_0-error:0.219966	validation_0-logloss:0.581306	validation_1-error:0.363636	validation_1-logloss:0.642139
# [105]	validation_0-error:0.216582	validation_0-logloss:0.580908	validation_1-error:0.363636	validation_1-logloss:0.641924
# [106]	validation_0-error:0.21489	validation_0-logloss:0.580373	validation_1-error:0.363636	validation_1-logloss:0.641856
# [107]	validation_0-error:0.213198	validation_0-logloss:0.579482	validation_1-error:0.363636	validation_1-logloss:0.641755
# [108]	validation_0-error:0.216582	validation_0-logloss:0.579052	validation_1-error:0.363636	validation_1-logloss:0.641335
# [109]	validation_0-error:0.213198	validation_0-logloss:0.578821	validation_1-error:0.363636	validation_1-logloss:0.641269
# [110]	validation_0-error:0.21489	validation_0-logloss:0.57781	validation_1-error:0.363636	validation_1-logloss:0.640723
# [111]	validation_0-error:0.21489	validation_0-logloss:0.577189	validation_1-error:0.348485	validation_1-logloss:0.640181
# [112]	validation_0-error:0.213198	validation_0-logloss:0.576389	validation_1-error:0.333333	validation_1-logloss:0.63997
# [113]	validation_0-error:0.209814	validation_0-logloss:0.575813	validation_1-error:0.318182	validation_1-logloss:0.639441
# [114]	validation_0-error:0.204738	validation_0-logloss:0.575167	validation_1-error:0.318182	validation_1-logloss:0.639416
# [115]	validation_0-error:0.208122	validation_0-logloss:0.57463	validation_1-error:0.318182	validation_1-logloss:0.639321
# [116]	validation_0-error:0.20643	validation_0-logloss:0.573864	validation_1-error:0.318182	validation_1-logloss:0.638794
# [117]	validation_0-error:0.20643	validation_0-logloss:0.573119	validation_1-error:0.333333	validation_1-logloss:0.639175
# [118]	validation_0-error:0.208122	validation_0-logloss:0.57276	validation_1-error:0.333333	validation_1-logloss:0.639071
# [119]	validation_0-error:0.20643	validation_0-logloss:0.572088	validation_1-error:0.318182	validation_1-logloss:0.638499
# [120]	validation_0-error:0.20643	validation_0-logloss:0.571298	validation_1-error:0.318182	validation_1-logloss:0.638115
# [121]	validation_0-error:0.20643	validation_0-logloss:0.570693	validation_1-error:0.318182	validation_1-logloss:0.637714
# [122]	validation_0-error:0.204738	validation_0-logloss:0.570077	validation_1-error:0.30303	validation_1-logloss:0.637657
# [123]	validation_0-error:0.20643	validation_0-logloss:0.569719	validation_1-error:0.318182	validation_1-logloss:0.638339
# [124]	validation_0-error:0.203046	validation_0-logloss:0.569289	validation_1-error:0.318182	validation_1-logloss:0.638693
# [125]	validation_0-error:0.203046	validation_0-logloss:0.568755	validation_1-error:0.318182	validation_1-logloss:0.638379
# [126]	validation_0-error:0.203046	validation_0-logloss:0.567774	validation_1-error:0.30303	validation_1-logloss:0.637588
# [127]	validation_0-error:0.19797	validation_0-logloss:0.566987	validation_1-error:0.318182	validation_1-logloss:0.637676
# [128]	validation_0-error:0.199662	validation_0-logloss:0.566633	validation_1-error:0.318182	validation_1-logloss:0.637847
# [129]	validation_0-error:0.196277	validation_0-logloss:0.566138	validation_1-error:0.333333	validation_1-logloss:0.638798
# [130]	validation_0-error:0.191201	validation_0-logloss:0.565518	validation_1-error:0.318182	validation_1-logloss:0.638508
# [131]	validation_0-error:0.194585	validation_0-logloss:0.56497	validation_1-error:0.318182	validation_1-logloss:0.638196
# [132]	validation_0-error:0.189509	validation_0-logloss:0.564463	validation_1-error:0.318182	validation_1-logloss:0.638033
# [133]	validation_0-error:0.187817	validation_0-logloss:0.564299	validation_1-error:0.318182	validation_1-logloss:0.638008
# [134]	validation_0-error:0.192893	validation_0-logloss:0.563801	validation_1-error:0.333333	validation_1-logloss:0.637685
# [135]	validation_0-error:0.189509	validation_0-logloss:0.563237	validation_1-error:0.333333	validation_1-logloss:0.63719
# [136]	validation_0-error:0.187817	validation_0-logloss:0.562341	validation_1-error:0.333333	validation_1-logloss:0.637101
# [137]	validation_0-error:0.189509	validation_0-logloss:0.56176	validation_1-error:0.318182	validation_1-logloss:0.636749
# [138]	validation_0-error:0.187817	validation_0-logloss:0.561339	validation_1-error:0.318182	validation_1-logloss:0.636437
# [139]	validation_0-error:0.189509	validation_0-logloss:0.560967	validation_1-error:0.318182	validation_1-logloss:0.636261
# [140]	validation_0-error:0.187817	validation_0-logloss:0.560422	validation_1-error:0.318182	validation_1-logloss:0.635921
# [141]	validation_0-error:0.189509	validation_0-logloss:0.5601	validation_1-error:0.318182	validation_1-logloss:0.635905
# [142]	validation_0-error:0.187817	validation_0-logloss:0.559738	validation_1-error:0.318182	validation_1-logloss:0.636076
# [143]	validation_0-error:0.189509	validation_0-logloss:0.559346	validation_1-error:0.318182	validation_1-logloss:0.635523
# [144]	validation_0-error:0.184433	validation_0-logloss:0.558795	validation_1-error:0.318182	validation_1-logloss:0.635596
# [145]	validation_0-error:0.189509	validation_0-logloss:0.558261	validation_1-error:0.318182	validation_1-logloss:0.634796
# [146]	validation_0-error:0.186125	validation_0-logloss:0.557341	validation_1-error:0.318182	validation_1-logloss:0.633833
# [147]	validation_0-error:0.186125	validation_0-logloss:0.557341	validation_1-error:0.318182	validation_1-logloss:0.633833
# [148]	validation_0-error:0.184433	validation_0-logloss:0.556782	validation_1-error:0.318182	validation_1-logloss:0.633824
# [149]	validation_0-error:0.186125	validation_0-logloss:0.556019	validation_1-error:0.333333	validation_1-logloss:0.633894
# [150]	validation_0-error:0.186125	validation_0-logloss:0.555644	validation_1-error:0.318182	validation_1-logloss:0.633569
# [151]	validation_0-error:0.184433	validation_0-logloss:0.55511	validation_1-error:0.318182	validation_1-logloss:0.633801
# [152]	validation_0-error:0.182741	validation_0-logloss:0.554365	validation_1-error:0.318182	validation_1-logloss:0.633252
# [153]	validation_0-error:0.182741	validation_0-logloss:0.553868	validation_1-error:0.30303	validation_1-logloss:0.633423
# [154]	validation_0-error:0.177665	validation_0-logloss:0.553309	validation_1-error:0.30303	validation_1-logloss:0.633229
# [155]	validation_0-error:0.182741	validation_0-logloss:0.552748	validation_1-error:0.318182	validation_1-logloss:0.632675
# [156]	validation_0-error:0.175973	validation_0-logloss:0.552159	validation_1-error:0.30303	validation_1-logloss:0.631974
# [157]	validation_0-error:0.174281	validation_0-logloss:0.55153	validation_1-error:0.30303	validation_1-logloss:0.631486
# [158]	validation_0-error:0.177665	validation_0-logloss:0.551388	validation_1-error:0.30303	validation_1-logloss:0.631559
# [159]	validation_0-error:0.177665	validation_0-logloss:0.550854	validation_1-error:0.30303	validation_1-logloss:0.631394
# [160]	validation_0-error:0.175973	validation_0-logloss:0.550522	validation_1-error:0.30303	validation_1-logloss:0.631129
# [161]	validation_0-error:0.175973	validation_0-logloss:0.550521	validation_1-error:0.30303	validation_1-logloss:0.631135
# [162]	validation_0-error:0.174281	validation_0-logloss:0.550164	validation_1-error:0.30303	validation_1-logloss:0.630998
# [163]	validation_0-error:0.174281	validation_0-logloss:0.549645	validation_1-error:0.30303	validation_1-logloss:0.63083
# [164]	validation_0-error:0.174281	validation_0-logloss:0.549639	validation_1-error:0.30303	validation_1-logloss:0.630855
# [165]	validation_0-error:0.175973	validation_0-logloss:0.549074	validation_1-error:0.30303	validation_1-logloss:0.631054
# [166]	validation_0-error:0.177665	validation_0-logloss:0.548722	validation_1-error:0.30303	validation_1-logloss:0.63077
# [167]	validation_0-error:0.179357	validation_0-logloss:0.54871	validation_1-error:0.30303	validation_1-logloss:0.630827
# [168]	validation_0-error:0.174281	validation_0-logloss:0.548289	validation_1-error:0.30303	validation_1-logloss:0.630429
# [169]	validation_0-error:0.174281	validation_0-logloss:0.547577	validation_1-error:0.30303	validation_1-logloss:0.630038
# [170]	validation_0-error:0.167513	validation_0-logloss:0.547319	validation_1-error:0.30303	validation_1-logloss:0.630224
# [171]	validation_0-error:0.169205	validation_0-logloss:0.547311	validation_1-error:0.30303	validation_1-logloss:0.630266
# [172]	validation_0-error:0.175973	validation_0-logloss:0.54711	validation_1-error:0.30303	validation_1-logloss:0.630221
# [173]	validation_0-error:0.174281	validation_0-logloss:0.54664	validation_1-error:0.30303	validation_1-logloss:0.63016
# [174]	validation_0-error:0.175973	validation_0-logloss:0.546636	validation_1-error:0.30303	validation_1-logloss:0.630183
# [175]	validation_0-error:0.175973	validation_0-logloss:0.54663	validation_1-error:0.30303	validation_1-logloss:0.630213
# [176]	validation_0-error:0.175973	validation_0-logloss:0.54662	validation_1-error:0.30303	validation_1-logloss:0.630274
# [177]	validation_0-error:0.177665	validation_0-logloss:0.546477	validation_1-error:0.30303	validation_1-logloss:0.629959
# [178]	validation_0-error:0.175973	validation_0-logloss:0.545763	validation_1-error:0.30303	validation_1-logloss:0.629911
# [179]	validation_0-error:0.174281	validation_0-logloss:0.545233	validation_1-error:0.318182	validation_1-logloss:0.629549
# [180]	validation_0-error:0.174281	validation_0-logloss:0.545232	validation_1-error:0.318182	validation_1-logloss:0.629557
# [181]	validation_0-error:0.174281	validation_0-logloss:0.544606	validation_1-error:0.30303	validation_1-logloss:0.62972
# [182]	validation_0-error:0.174281	validation_0-logloss:0.54429	validation_1-error:0.318182	validation_1-logloss:0.629726
# [183]	validation_0-error:0.174281	validation_0-logloss:0.544289	validation_1-error:0.318182	validation_1-logloss:0.629732
# [184]	validation_0-error:0.174281	validation_0-logloss:0.544287	validation_1-error:0.318182	validation_1-logloss:0.629748
# [185]	validation_0-error:0.174281	validation_0-logloss:0.544286	validation_1-error:0.318182	validation_1-logloss:0.629754
# [186]	validation_0-error:0.172589	validation_0-logloss:0.543719	validation_1-error:0.318182	validation_1-logloss:0.630197
# [187]	validation_0-error:0.172589	validation_0-logloss:0.543053	validation_1-error:0.30303	validation_1-logloss:0.629879
# [188]	validation_0-error:0.170897	validation_0-logloss:0.542876	validation_1-error:0.30303	validation_1-logloss:0.630466
# [189]	validation_0-error:0.170897	validation_0-logloss:0.542876	validation_1-error:0.30303	validation_1-logloss:0.63047
# Stopping. Best iteration:
# [179]	validation_0-error:0.174281	validation_0-logloss:0.545233	validation_1-error:0.318182	validation_1-logloss:0.629549
#
# Accuracy: 68.18%

# %% [markdown]
# ### Display the Classification Report

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

print ('Accuracy:', accuracy_score(y_test_a, predictions_audio_test))
print ('F1 score:', f1_score(y_test_a, predictions_audio_test))
print ('Recall:', recall_score(y_test_a, predictions_audio_test))
print ('Precision:', precision_score(y_test_a, predictions_audio_test))
print ('\n clasification report:\n', classification_report(y_test_a,predictions_audio_test))
print ('\n confussion matrix:\n',confusion_matrix(y_test_a, predictions_audio_test))
# Out:
# Accuracy: 0.6818181818181818
# F1 score: 0.5882352941176471
# Recall: 0.4411764705882353
# Precision: 0.8823529411764706
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74        32
#            1       0.88      0.44      0.59        34
#
#    micro avg       0.68      0.68      0.68        66
#    macro avg       0.75      0.69      0.66        66
# weighted avg       0.75      0.68      0.66        66
#
#
#  confussion matrix:
#  [[30  2]
#  [19 15]]

# %% [markdown]
# ###  XGboost is applied on gaze data

# %%
from xgboost.sklearn import XGBClassifier
model_g = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=3, 
                      gamma=10)
eval_set = [(X_train_g, y_train_g), (X_test_g, y_test_g)]
model_g.fit(X_train_g, y_train_g, early_stopping_rounds=10, eval_metric=["error", "logloss"], eval_set=eval_set,verbose=True)
# make predictions for test data
y_pred = model_g.predict(X_test_g)
predictions_gaze_test = [round(value) for value in y_pred]
# evaluate predictions
accuracy = metrics.accuracy_score(y_test_g, predictions_gaze_test)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# retrieve performance metrics
results = model_g.evals_result()
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# plot classification error
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Test')
ax.legend()
plt.ylabel('Classification Error')
plt.title('XGBoost Classification Error')
plt.show()
# Out:
# [0]	validation_0-error:0.353638	validation_0-logloss:0.691904	validation_1-error:0.454545	validation_1-logloss:0.692584
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-error:0.340102	validation_0-logloss:0.691111	validation_1-error:0.409091	validation_1-logloss:0.692089
# [2]	validation_0-error:0.323181	validation_0-logloss:0.689803	validation_1-error:0.439394	validation_1-logloss:0.691253
# [3]	validation_0-error:0.324873	validation_0-logloss:0.688705	validation_1-error:0.439394	validation_1-logloss:0.690477
# [4]	validation_0-error:0.333333	validation_0-logloss:0.687331	validation_1-error:0.409091	validation_1-logloss:0.689018
# [5]	validation_0-error:0.324873	validation_0-logloss:0.686364	validation_1-error:0.424242	validation_1-logloss:0.689028
# [6]	validation_0-error:0.323181	validation_0-logloss:0.685649	validation_1-error:0.409091	validation_1-logloss:0.68843
# [7]	validation_0-error:0.319797	validation_0-logloss:0.684539	validation_1-error:0.454545	validation_1-logloss:0.687819
# [8]	validation_0-error:0.319797	validation_0-logloss:0.683205	validation_1-error:0.454545	validation_1-logloss:0.686898
# [9]	validation_0-error:0.319797	validation_0-logloss:0.682093	validation_1-error:0.439394	validation_1-logloss:0.68607
# [10]	validation_0-error:0.319797	validation_0-logloss:0.68098	validation_1-error:0.454545	validation_1-logloss:0.685134
# [11]	validation_0-error:0.318105	validation_0-logloss:0.679936	validation_1-error:0.393939	validation_1-logloss:0.684191
# [12]	validation_0-error:0.314721	validation_0-logloss:0.679559	validation_1-error:0.439394	validation_1-logloss:0.684026
# [13]	validation_0-error:0.316413	validation_0-logloss:0.678502	validation_1-error:0.439394	validation_1-logloss:0.683236
# [14]	validation_0-error:0.318105	validation_0-logloss:0.677309	validation_1-error:0.439394	validation_1-logloss:0.682041
# [15]	validation_0-error:0.319797	validation_0-logloss:0.676595	validation_1-error:0.439394	validation_1-logloss:0.681664
# [16]	validation_0-error:0.319797	validation_0-logloss:0.676272	validation_1-error:0.424242	validation_1-logloss:0.68174
# [17]	validation_0-error:0.333333	validation_0-logloss:0.675277	validation_1-error:0.409091	validation_1-logloss:0.681203
# [18]	validation_0-error:0.331641	validation_0-logloss:0.674771	validation_1-error:0.409091	validation_1-logloss:0.681073
# [19]	validation_0-error:0.333333	validation_0-logloss:0.673572	validation_1-error:0.409091	validation_1-logloss:0.680257
# [20]	validation_0-error:0.331641	validation_0-logloss:0.672635	validation_1-error:0.424242	validation_1-logloss:0.679683
# [21]	validation_0-error:0.333333	validation_0-logloss:0.671681	validation_1-error:0.439394	validation_1-logloss:0.67851
# [22]	validation_0-error:0.343486	validation_0-logloss:0.671061	validation_1-error:0.424242	validation_1-logloss:0.67806
# [23]	validation_0-error:0.335025	validation_0-logloss:0.670323	validation_1-error:0.439394	validation_1-logloss:0.67761
# [24]	validation_0-error:0.336717	validation_0-logloss:0.669974	validation_1-error:0.439394	validation_1-logloss:0.677429
# [25]	validation_0-error:0.336717	validation_0-logloss:0.668881	validation_1-error:0.439394	validation_1-logloss:0.676727
# [26]	validation_0-error:0.336717	validation_0-logloss:0.668244	validation_1-error:0.439394	validation_1-logloss:0.67637
# [27]	validation_0-error:0.345178	validation_0-logloss:0.667761	validation_1-error:0.439394	validation_1-logloss:0.67629
# [28]	validation_0-error:0.343486	validation_0-logloss:0.666702	validation_1-error:0.439394	validation_1-logloss:0.675635
# [29]	validation_0-error:0.343486	validation_0-logloss:0.666137	validation_1-error:0.439394	validation_1-logloss:0.675432
# [30]	validation_0-error:0.345178	validation_0-logloss:0.665468	validation_1-error:0.439394	validation_1-logloss:0.674883
# [31]	validation_0-error:0.350254	validation_0-logloss:0.664834	validation_1-error:0.439394	validation_1-logloss:0.674564
# [32]	validation_0-error:0.34687	validation_0-logloss:0.66423	validation_1-error:0.439394	validation_1-logloss:0.674138
# [33]	validation_0-error:0.341794	validation_0-logloss:0.663182	validation_1-error:0.439394	validation_1-logloss:0.672942
# [34]	validation_0-error:0.340102	validation_0-logloss:0.662634	validation_1-error:0.439394	validation_1-logloss:0.67242
# [35]	validation_0-error:0.343486	validation_0-logloss:0.661907	validation_1-error:0.424242	validation_1-logloss:0.671912
# [36]	validation_0-error:0.34687	validation_0-logloss:0.661378	validation_1-error:0.424242	validation_1-logloss:0.671778
# [37]	validation_0-error:0.345178	validation_0-logloss:0.660738	validation_1-error:0.424242	validation_1-logloss:0.671383
# [38]	validation_0-error:0.345178	validation_0-logloss:0.659966	validation_1-error:0.424242	validation_1-logloss:0.670552
# [39]	validation_0-error:0.338409	validation_0-logloss:0.659255	validation_1-error:0.424242	validation_1-logloss:0.670356
# [40]	validation_0-error:0.341794	validation_0-logloss:0.658786	validation_1-error:0.424242	validation_1-logloss:0.670325
# [41]	validation_0-error:0.338409	validation_0-logloss:0.658479	validation_1-error:0.424242	validation_1-logloss:0.670227
# [42]	validation_0-error:0.338409	validation_0-logloss:0.658131	validation_1-error:0.424242	validation_1-logloss:0.670189
# [43]	validation_0-error:0.338409	validation_0-logloss:0.657597	validation_1-error:0.424242	validation_1-logloss:0.670024
# [44]	validation_0-error:0.341794	validation_0-logloss:0.65738	validation_1-error:0.424242	validation_1-logloss:0.669688
# [45]	validation_0-error:0.340102	validation_0-logloss:0.656734	validation_1-error:0.424242	validation_1-logloss:0.669426
# [46]	validation_0-error:0.341794	validation_0-logloss:0.656448	validation_1-error:0.424242	validation_1-logloss:0.669398
# [47]	validation_0-error:0.340102	validation_0-logloss:0.655904	validation_1-error:0.424242	validation_1-logloss:0.669215
# [48]	validation_0-error:0.341794	validation_0-logloss:0.655257	validation_1-error:0.439394	validation_1-logloss:0.668817
# [49]	validation_0-error:0.340102	validation_0-logloss:0.654764	validation_1-error:0.424242	validation_1-logloss:0.668674
# [50]	validation_0-error:0.340102	validation_0-logloss:0.654324	validation_1-error:0.424242	validation_1-logloss:0.668412
# [51]	validation_0-error:0.336717	validation_0-logloss:0.653686	validation_1-error:0.439394	validation_1-logloss:0.668036
# [52]	validation_0-error:0.343486	validation_0-logloss:0.653421	validation_1-error:0.439394	validation_1-logloss:0.667906
# [53]	validation_0-error:0.338409	validation_0-logloss:0.653159	validation_1-error:0.439394	validation_1-logloss:0.667758
# [54]	validation_0-error:0.340102	validation_0-logloss:0.652659	validation_1-error:0.439394	validation_1-logloss:0.66797
# [55]	validation_0-error:0.338409	validation_0-logloss:0.652418	validation_1-error:0.439394	validation_1-logloss:0.667853
# [56]	validation_0-error:0.338409	validation_0-logloss:0.651454	validation_1-error:0.439394	validation_1-logloss:0.667222
# [57]	validation_0-error:0.340102	validation_0-logloss:0.6509	validation_1-error:0.439394	validation_1-logloss:0.666919
# [58]	validation_0-error:0.340102	validation_0-logloss:0.650464	validation_1-error:0.439394	validation_1-logloss:0.666763
# [59]	validation_0-error:0.340102	validation_0-logloss:0.649907	validation_1-error:0.439394	validation_1-logloss:0.666882
# [60]	validation_0-error:0.341794	validation_0-logloss:0.649418	validation_1-error:0.439394	validation_1-logloss:0.666302
# [61]	validation_0-error:0.338409	validation_0-logloss:0.648701	validation_1-error:0.439394	validation_1-logloss:0.6657
# [62]	validation_0-error:0.338409	validation_0-logloss:0.64844	validation_1-error:0.439394	validation_1-logloss:0.665579
# [63]	validation_0-error:0.338409	validation_0-logloss:0.647991	validation_1-error:0.439394	validation_1-logloss:0.665101
# [64]	validation_0-error:0.338409	validation_0-logloss:0.647761	validation_1-error:0.439394	validation_1-logloss:0.664983
# [65]	validation_0-error:0.338409	validation_0-logloss:0.647361	validation_1-error:0.439394	validation_1-logloss:0.664823
# [66]	validation_0-error:0.338409	validation_0-logloss:0.646938	validation_1-error:0.439394	validation_1-logloss:0.664493
# [67]	validation_0-error:0.338409	validation_0-logloss:0.646516	validation_1-error:0.439394	validation_1-logloss:0.664107
# [68]	validation_0-error:0.338409	validation_0-logloss:0.646227	validation_1-error:0.439394	validation_1-logloss:0.664039
# [69]	validation_0-error:0.340102	validation_0-logloss:0.645326	validation_1-error:0.439394	validation_1-logloss:0.663541
# [70]	validation_0-error:0.340102	validation_0-logloss:0.644694	validation_1-error:0.439394	validation_1-logloss:0.662591
# [71]	validation_0-error:0.340102	validation_0-logloss:0.644108	validation_1-error:0.439394	validation_1-logloss:0.662422
# [72]	validation_0-error:0.341794	validation_0-logloss:0.643445	validation_1-error:0.439394	validation_1-logloss:0.662126
# [73]	validation_0-error:0.340102	validation_0-logloss:0.643252	validation_1-error:0.439394	validation_1-logloss:0.662016
# [74]	validation_0-error:0.338409	validation_0-logloss:0.642779	validation_1-error:0.439394	validation_1-logloss:0.661711
# [75]	validation_0-error:0.338409	validation_0-logloss:0.642774	validation_1-error:0.439394	validation_1-logloss:0.661718
# [76]	validation_0-error:0.340102	validation_0-logloss:0.642131	validation_1-error:0.439394	validation_1-logloss:0.661247
# [77]	validation_0-error:0.340102	validation_0-logloss:0.641557	validation_1-error:0.439394	validation_1-logloss:0.660734
# [78]	validation_0-error:0.340102	validation_0-logloss:0.641307	validation_1-error:0.439394	validation_1-logloss:0.660616
# [79]	validation_0-error:0.343486	validation_0-logloss:0.640705	validation_1-error:0.439394	validation_1-logloss:0.660028
# [80]	validation_0-error:0.338409	validation_0-logloss:0.640302	validation_1-error:0.439394	validation_1-logloss:0.659667
# [81]	validation_0-error:0.335025	validation_0-logloss:0.639749	validation_1-error:0.439394	validation_1-logloss:0.659687
# [82]	validation_0-error:0.340102	validation_0-logloss:0.639224	validation_1-error:0.439394	validation_1-logloss:0.659562
# [83]	validation_0-error:0.340102	validation_0-logloss:0.638894	validation_1-error:0.439394	validation_1-logloss:0.659184
# [84]	validation_0-error:0.340102	validation_0-logloss:0.638405	validation_1-error:0.439394	validation_1-logloss:0.659042
# [85]	validation_0-error:0.336717	validation_0-logloss:0.637976	validation_1-error:0.439394	validation_1-logloss:0.65875
# [86]	validation_0-error:0.338409	validation_0-logloss:0.637959	validation_1-error:0.439394	validation_1-logloss:0.658779
# [87]	validation_0-error:0.338409	validation_0-logloss:0.637744	validation_1-error:0.439394	validation_1-logloss:0.658941
# [88]	validation_0-error:0.336717	validation_0-logloss:0.637529	validation_1-error:0.439394	validation_1-logloss:0.658961
# [89]	validation_0-error:0.338409	validation_0-logloss:0.63752	validation_1-error:0.439394	validation_1-logloss:0.658978
# [90]	validation_0-error:0.338409	validation_0-logloss:0.637112	validation_1-error:0.439394	validation_1-logloss:0.658691
# [91]	validation_0-error:0.336717	validation_0-logloss:0.636918	validation_1-error:0.439394	validation_1-logloss:0.658583
# [92]	validation_0-error:0.335025	validation_0-logloss:0.63672	validation_1-error:0.439394	validation_1-logloss:0.658694
# [93]	validation_0-error:0.335025	validation_0-logloss:0.636163	validation_1-error:0.439394	validation_1-logloss:0.658259
# [94]	validation_0-error:0.335025	validation_0-logloss:0.635546	validation_1-error:0.439394	validation_1-logloss:0.657539
# [95]	validation_0-error:0.335025	validation_0-logloss:0.635525	validation_1-error:0.439394	validation_1-logloss:0.65758
# [96]	validation_0-error:0.335025	validation_0-logloss:0.635508	validation_1-error:0.439394	validation_1-logloss:0.657614
# [97]	validation_0-error:0.335025	validation_0-logloss:0.635495	validation_1-error:0.439394	validation_1-logloss:0.65764
# [98]	validation_0-error:0.335025	validation_0-logloss:0.635147	validation_1-error:0.439394	validation_1-logloss:0.657622
# [99]	validation_0-error:0.335025	validation_0-logloss:0.63513	validation_1-error:0.439394	validation_1-logloss:0.657656
# [100]	validation_0-error:0.333333	validation_0-logloss:0.635122	validation_1-error:0.439394	validation_1-logloss:0.657675
# [101]	validation_0-error:0.335025	validation_0-logloss:0.634755	validation_1-error:0.439394	validation_1-logloss:0.657203
# [102]	validation_0-error:0.335025	validation_0-logloss:0.634609	validation_1-error:0.439394	validation_1-logloss:0.657198
# [103]	validation_0-error:0.335025	validation_0-logloss:0.634589	validation_1-error:0.439394	validation_1-logloss:0.65724
# [104]	validation_0-error:0.335025	validation_0-logloss:0.634183	validation_1-error:0.439394	validation_1-logloss:0.656913
# [105]	validation_0-error:0.335025	validation_0-logloss:0.634177	validation_1-error:0.439394	validation_1-logloss:0.656928
# [106]	validation_0-error:0.335025	validation_0-logloss:0.633564	validation_1-error:0.439394	validation_1-logloss:0.656281
# [107]	validation_0-error:0.335025	validation_0-logloss:0.633547	validation_1-error:0.439394	validation_1-logloss:0.656319
# [108]	validation_0-error:0.338409	validation_0-logloss:0.633151	validation_1-error:0.424242	validation_1-logloss:0.655786
# [109]	validation_0-error:0.338409	validation_0-logloss:0.63313	validation_1-error:0.424242	validation_1-logloss:0.655837
# [110]	validation_0-error:0.338409	validation_0-logloss:0.633121	validation_1-error:0.424242	validation_1-logloss:0.655857
# [111]	validation_0-error:0.338409	validation_0-logloss:0.633114	validation_1-error:0.424242	validation_1-logloss:0.655874
# [112]	validation_0-error:0.338409	validation_0-logloss:0.633097	validation_1-error:0.424242	validation_1-logloss:0.655917
# [113]	validation_0-error:0.335025	validation_0-logloss:0.632935	validation_1-error:0.439394	validation_1-logloss:0.656017
# [114]	validation_0-error:0.338409	validation_0-logloss:0.632594	validation_1-error:0.439394	validation_1-logloss:0.655883
# [115]	validation_0-error:0.338409	validation_0-logloss:0.632586	validation_1-error:0.439394	validation_1-logloss:0.655904
# [116]	validation_0-error:0.338409	validation_0-logloss:0.632267	validation_1-error:0.424242	validation_1-logloss:0.655316
# [117]	validation_0-error:0.338409	validation_0-logloss:0.632258	validation_1-error:0.424242	validation_1-logloss:0.655341
# [118]	validation_0-error:0.336717	validation_0-logloss:0.631947	validation_1-error:0.424242	validation_1-logloss:0.65498
# [119]	validation_0-error:0.338409	validation_0-logloss:0.631942	validation_1-error:0.424242	validation_1-logloss:0.654994
# [120]	validation_0-error:0.338409	validation_0-logloss:0.63193	validation_1-error:0.424242	validation_1-logloss:0.655028
# [121]	validation_0-error:0.338409	validation_0-logloss:0.631921	validation_1-error:0.424242	validation_1-logloss:0.655051
# [122]	validation_0-error:0.338409	validation_0-logloss:0.631422	validation_1-error:0.424242	validation_1-logloss:0.654654
# [123]	validation_0-error:0.338409	validation_0-logloss:0.631417	validation_1-error:0.424242	validation_1-logloss:0.654667
# [124]	validation_0-error:0.336717	validation_0-logloss:0.630899	validation_1-error:0.424242	validation_1-logloss:0.654664
# [125]	validation_0-error:0.336717	validation_0-logloss:0.630528	validation_1-error:0.424242	validation_1-logloss:0.654519
# [126]	validation_0-error:0.336717	validation_0-logloss:0.630498	validation_1-error:0.424242	validation_1-logloss:0.654606
# [127]	validation_0-error:0.336717	validation_0-logloss:0.630491	validation_1-error:0.424242	validation_1-logloss:0.654628
# [128]	validation_0-error:0.336717	validation_0-logloss:0.630478	validation_1-error:0.424242	validation_1-logloss:0.654669
# [129]	validation_0-error:0.336717	validation_0-logloss:0.630466	validation_1-error:0.424242	validation_1-logloss:0.654706
# [130]	validation_0-error:0.336717	validation_0-logloss:0.630162	validation_1-error:0.424242	validation_1-logloss:0.65464
# [131]	validation_0-error:0.336717	validation_0-logloss:0.629716	validation_1-error:0.424242	validation_1-logloss:0.654417
# [132]	validation_0-error:0.338409	validation_0-logloss:0.629698	validation_1-error:0.424242	validation_1-logloss:0.654474
# [133]	validation_0-error:0.338409	validation_0-logloss:0.629695	validation_1-error:0.424242	validation_1-logloss:0.654485
# [134]	validation_0-error:0.338409	validation_0-logloss:0.629693	validation_1-error:0.424242	validation_1-logloss:0.654491
# [135]	validation_0-error:0.338409	validation_0-logloss:0.629293	validation_1-error:0.424242	validation_1-logloss:0.654154
# [136]	validation_0-error:0.333333	validation_0-logloss:0.628833	validation_1-error:0.424242	validation_1-logloss:0.654073
# [137]	validation_0-error:0.335025	validation_0-logloss:0.628816	validation_1-error:0.424242	validation_1-logloss:0.654132
# [138]	validation_0-error:0.338409	validation_0-logloss:0.628376	validation_1-error:0.424242	validation_1-logloss:0.65389
# [139]	validation_0-error:0.338409	validation_0-logloss:0.628369	validation_1-error:0.424242	validation_1-logloss:0.653914
# [140]	validation_0-error:0.335025	validation_0-logloss:0.627874	validation_1-error:0.424242	validation_1-logloss:0.653509
# [141]	validation_0-error:0.335025	validation_0-logloss:0.627874	validation_1-error:0.424242	validation_1-logloss:0.653509
# [142]	validation_0-error:0.335025	validation_0-logloss:0.627574	validation_1-error:0.424242	validation_1-logloss:0.653724
# [143]	validation_0-error:0.333333	validation_0-logloss:0.627265	validation_1-error:0.424242	validation_1-logloss:0.653764
# [144]	validation_0-error:0.331641	validation_0-logloss:0.626933	validation_1-error:0.424242	validation_1-logloss:0.653732
# [145]	validation_0-error:0.335025	validation_0-logloss:0.62643	validation_1-error:0.424242	validation_1-logloss:0.653367
# [146]	validation_0-error:0.331641	validation_0-logloss:0.625902	validation_1-error:0.424242	validation_1-logloss:0.652919
# [147]	validation_0-error:0.331641	validation_0-logloss:0.625902	validation_1-error:0.424242	validation_1-logloss:0.652919
# [148]	validation_0-error:0.331641	validation_0-logloss:0.625899	validation_1-error:0.424242	validation_1-logloss:0.65293
# [149]	validation_0-error:0.331641	validation_0-logloss:0.625896	validation_1-error:0.424242	validation_1-logloss:0.652943
# [150]	validation_0-error:0.331641	validation_0-logloss:0.625889	validation_1-error:0.424242	validation_1-logloss:0.652967
# [151]	validation_0-error:0.333333	validation_0-logloss:0.625881	validation_1-error:0.424242	validation_1-logloss:0.652999
# [152]	validation_0-error:0.333333	validation_0-logloss:0.625879	validation_1-error:0.424242	validation_1-logloss:0.653009
# [153]	validation_0-error:0.333333	validation_0-logloss:0.625705	validation_1-error:0.424242	validation_1-logloss:0.652907
# [154]	validation_0-error:0.333333	validation_0-logloss:0.625699	validation_1-error:0.424242	validation_1-logloss:0.652932
# [155]	validation_0-error:0.333333	validation_0-logloss:0.625171	validation_1-error:0.424242	validation_1-logloss:0.652366
# [156]	validation_0-error:0.333333	validation_0-logloss:0.625169	validation_1-error:0.424242	validation_1-logloss:0.652375
# [157]	validation_0-error:0.333333	validation_0-logloss:0.624689	validation_1-error:0.424242	validation_1-logloss:0.652261
# [158]	validation_0-error:0.333333	validation_0-logloss:0.624682	validation_1-error:0.424242	validation_1-logloss:0.652289
# [159]	validation_0-error:0.331641	validation_0-logloss:0.624229	validation_1-error:0.424242	validation_1-logloss:0.651992
# [160]	validation_0-error:0.331641	validation_0-logloss:0.624232	validation_1-error:0.424242	validation_1-logloss:0.65198
# [161]	validation_0-error:0.333333	validation_0-logloss:0.623733	validation_1-error:0.424242	validation_1-logloss:0.651418
# [162]	validation_0-error:0.333333	validation_0-logloss:0.623728	validation_1-error:0.424242	validation_1-logloss:0.651438
# [163]	validation_0-error:0.333333	validation_0-logloss:0.623722	validation_1-error:0.424242	validation_1-logloss:0.651466
# [164]	validation_0-error:0.331641	validation_0-logloss:0.623717	validation_1-error:0.424242	validation_1-logloss:0.651486
# [165]	validation_0-error:0.331641	validation_0-logloss:0.623714	validation_1-error:0.424242	validation_1-logloss:0.651502
# [166]	validation_0-error:0.331641	validation_0-logloss:0.623709	validation_1-error:0.424242	validation_1-logloss:0.651522
# [167]	validation_0-error:0.331641	validation_0-logloss:0.623698	validation_1-error:0.424242	validation_1-logloss:0.651573
# [168]	validation_0-error:0.331641	validation_0-logloss:0.623243	validation_1-error:0.424242	validation_1-logloss:0.651081
# [169]	validation_0-error:0.331641	validation_0-logloss:0.623241	validation_1-error:0.424242	validation_1-logloss:0.651091
# [170]	validation_0-error:0.331641	validation_0-logloss:0.623235	validation_1-error:0.424242	validation_1-logloss:0.651116
# [171]	validation_0-error:0.329949	validation_0-logloss:0.623229	validation_1-error:0.424242	validation_1-logloss:0.651149
# [172]	validation_0-error:0.331641	validation_0-logloss:0.622757	validation_1-error:0.439394	validation_1-logloss:0.651158
# [173]	validation_0-error:0.329949	validation_0-logloss:0.622751	validation_1-error:0.439394	validation_1-logloss:0.651188
# [174]	validation_0-error:0.329949	validation_0-logloss:0.622747	validation_1-error:0.439394	validation_1-logloss:0.65121
# [175]	validation_0-error:0.329949	validation_0-logloss:0.622742	validation_1-error:0.439394	validation_1-logloss:0.651237
# [176]	validation_0-error:0.329949	validation_0-logloss:0.622731	validation_1-error:0.424242	validation_1-logloss:0.651296
# [177]	validation_0-error:0.331641	validation_0-logloss:0.622578	validation_1-error:0.439394	validation_1-logloss:0.651355
# [178]	validation_0-error:0.331641	validation_0-logloss:0.622575	validation_1-error:0.439394	validation_1-logloss:0.651372
# Stopping. Best iteration:
# [168]	validation_0-error:0.331641	validation_0-logloss:0.623243	validation_1-error:0.424242	validation_1-logloss:0.651081
#
# Accuracy: 57.58%

# %% [markdown]
# ### Display the Metric Scores and Classification Report

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

print ('Accuracy:', accuracy_score(y_test_g, predictions_gaze_test))
print ('F1 score:', f1_score(y_test_g, predictions_gaze_test))
print ('Recall:', recall_score(y_test_g, predictions_gaze_test))
print ('Precision:', precision_score(y_test_g, predictions_gaze_test))
print ('\n clasification report:\n', classification_report(y_test_g,predictions_gaze_test))
print ('\n confussion matrix:\n',confusion_matrix(y_test_g, predictions_gaze_test))
# Out:
# Accuracy: 0.5757575757575758
# F1 score: 0.39130434782608703
# Recall: 0.2647058823529412
# Precision: 0.75
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.91      0.67        32
#            1       0.75      0.26      0.39        34
#
#    micro avg       0.58      0.58      0.58        66
#    macro avg       0.64      0.59      0.53        66
# weighted avg       0.65      0.58      0.53        66
#
#
#  confussion matrix:
#  [[29  3]
#  [25  9]]

# %% [markdown]
# ### XGboost is applied on Micro_Expression data

# %%
from xgboost.sklearn import XGBClassifier
model_m = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=3, 
                      gamma=10)
eval_set = [(X_train_m, y_train_m), (X_test_m, y_test_m)]
model_m.fit(X_train_m, y_train_m, early_stopping_rounds=10, eval_metric=["error", "logloss"], eval_set=eval_set,verbose=True)
# make predictions for test data
y_pred = model_m.predict(X_test_m)
predictions_mexp_test = [round(value) for value in y_pred]
# evaluate predictions
accuracy = metrics.accuracy_score(y_test_m, predictions_mexp_test)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# retrieve performance metrics
results = model_m.evals_result()
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss')
plt.show()
# plot classification error
fig, ax = plt.subplots()
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Test')
ax.legend()
plt.ylabel('Classification Error')
plt.title('XGBoost Classification Error')
plt.show()
# Out:
# [0]	validation_0-error:0.358714	validation_0-logloss:0.692225	validation_1-error:0.424242	validation_1-logloss:0.692692
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-error:0.331641	validation_0-logloss:0.691215	validation_1-error:0.378788	validation_1-logloss:0.691991
# [2]	validation_0-error:0.328257	validation_0-logloss:0.690237	validation_1-error:0.378788	validation_1-logloss:0.691461
# [3]	validation_0-error:0.331641	validation_0-logloss:0.689652	validation_1-error:0.378788	validation_1-logloss:0.69046
# [4]	validation_0-error:0.328257	validation_0-logloss:0.688716	validation_1-error:0.348485	validation_1-logloss:0.689454
# [5]	validation_0-error:0.333333	validation_0-logloss:0.687984	validation_1-error:0.363636	validation_1-logloss:0.688962
# [6]	validation_0-error:0.316413	validation_0-logloss:0.687008	validation_1-error:0.378788	validation_1-logloss:0.688221
# [7]	validation_0-error:0.314721	validation_0-logloss:0.686137	validation_1-error:0.378788	validation_1-logloss:0.687672
# [8]	validation_0-error:0.313029	validation_0-logloss:0.685338	validation_1-error:0.378788	validation_1-logloss:0.6871
# [9]	validation_0-error:0.296108	validation_0-logloss:0.684487	validation_1-error:0.378788	validation_1-logloss:0.686657
# [10]	validation_0-error:0.304569	validation_0-logloss:0.683856	validation_1-error:0.393939	validation_1-logloss:0.686427
# [11]	validation_0-error:0.302876	validation_0-logloss:0.682913	validation_1-error:0.378788	validation_1-logloss:0.686125
# [12]	validation_0-error:0.314721	validation_0-logloss:0.681978	validation_1-error:0.363636	validation_1-logloss:0.68579
# [13]	validation_0-error:0.306261	validation_0-logloss:0.681191	validation_1-error:0.363636	validation_1-logloss:0.685449
# [14]	validation_0-error:0.306261	validation_0-logloss:0.680301	validation_1-error:0.363636	validation_1-logloss:0.684394
# [15]	validation_0-error:0.309645	validation_0-logloss:0.679383	validation_1-error:0.333333	validation_1-logloss:0.683323
# [16]	validation_0-error:0.314721	validation_0-logloss:0.678421	validation_1-error:0.363636	validation_1-logloss:0.683031
# [17]	validation_0-error:0.311337	validation_0-logloss:0.677846	validation_1-error:0.363636	validation_1-logloss:0.682628
# [18]	validation_0-error:0.313029	validation_0-logloss:0.677478	validation_1-error:0.363636	validation_1-logloss:0.682069
# [19]	validation_0-error:0.2978	validation_0-logloss:0.676672	validation_1-error:0.363636	validation_1-logloss:0.681308
# [20]	validation_0-error:0.299492	validation_0-logloss:0.675777	validation_1-error:0.363636	validation_1-logloss:0.681039
# [21]	validation_0-error:0.304569	validation_0-logloss:0.674986	validation_1-error:0.348485	validation_1-logloss:0.680669
# [22]	validation_0-error:0.307953	validation_0-logloss:0.674723	validation_1-error:0.363636	validation_1-logloss:0.680294
# [23]	validation_0-error:0.314721	validation_0-logloss:0.674182	validation_1-error:0.363636	validation_1-logloss:0.679919
# [24]	validation_0-error:0.313029	validation_0-logloss:0.673664	validation_1-error:0.363636	validation_1-logloss:0.679284
# [25]	validation_0-error:0.311337	validation_0-logloss:0.672735	validation_1-error:0.363636	validation_1-logloss:0.678437
# [26]	validation_0-error:0.307953	validation_0-logloss:0.672416	validation_1-error:0.363636	validation_1-logloss:0.677992
# [27]	validation_0-error:0.304569	validation_0-logloss:0.671825	validation_1-error:0.363636	validation_1-logloss:0.677464
# [28]	validation_0-error:0.306261	validation_0-logloss:0.671139	validation_1-error:0.348485	validation_1-logloss:0.676972
# [29]	validation_0-error:0.2978	validation_0-logloss:0.670279	validation_1-error:0.363636	validation_1-logloss:0.676416
# [30]	validation_0-error:0.296108	validation_0-logloss:0.669696	validation_1-error:0.363636	validation_1-logloss:0.675699
# [31]	validation_0-error:0.296108	validation_0-logloss:0.668992	validation_1-error:0.333333	validation_1-logloss:0.675275
# [32]	validation_0-error:0.302876	validation_0-logloss:0.668486	validation_1-error:0.333333	validation_1-logloss:0.674755
# [33]	validation_0-error:0.301184	validation_0-logloss:0.667684	validation_1-error:0.348485	validation_1-logloss:0.674329
# [34]	validation_0-error:0.306261	validation_0-logloss:0.667101	validation_1-error:0.333333	validation_1-logloss:0.673788
# [35]	validation_0-error:0.313029	validation_0-logloss:0.666207	validation_1-error:0.333333	validation_1-logloss:0.673127
# [36]	validation_0-error:0.307953	validation_0-logloss:0.665548	validation_1-error:0.348485	validation_1-logloss:0.67243
# [37]	validation_0-error:0.307953	validation_0-logloss:0.664911	validation_1-error:0.348485	validation_1-logloss:0.671866
# [38]	validation_0-error:0.313029	validation_0-logloss:0.664344	validation_1-error:0.363636	validation_1-logloss:0.671778
# [39]	validation_0-error:0.311337	validation_0-logloss:0.66408	validation_1-error:0.363636	validation_1-logloss:0.671657
# [40]	validation_0-error:0.311337	validation_0-logloss:0.663529	validation_1-error:0.363636	validation_1-logloss:0.6709
# [41]	validation_0-error:0.313029	validation_0-logloss:0.663009	validation_1-error:0.363636	validation_1-logloss:0.67062
# [42]	validation_0-error:0.313029	validation_0-logloss:0.661994	validation_1-error:0.348485	validation_1-logloss:0.669968
# [43]	validation_0-error:0.311337	validation_0-logloss:0.661652	validation_1-error:0.348485	validation_1-logloss:0.669904
# [44]	validation_0-error:0.314721	validation_0-logloss:0.660805	validation_1-error:0.348485	validation_1-logloss:0.669171
# [45]	validation_0-error:0.307953	validation_0-logloss:0.660441	validation_1-error:0.348485	validation_1-logloss:0.669109
# [46]	validation_0-error:0.306261	validation_0-logloss:0.659709	validation_1-error:0.348485	validation_1-logloss:0.669423
# [47]	validation_0-error:0.302876	validation_0-logloss:0.658997	validation_1-error:0.333333	validation_1-logloss:0.668771
# [48]	validation_0-error:0.307953	validation_0-logloss:0.658539	validation_1-error:0.348485	validation_1-logloss:0.668446
# [49]	validation_0-error:0.301184	validation_0-logloss:0.65822	validation_1-error:0.333333	validation_1-logloss:0.668404
# [50]	validation_0-error:0.304569	validation_0-logloss:0.65754	validation_1-error:0.333333	validation_1-logloss:0.667537
# [51]	validation_0-error:0.2978	validation_0-logloss:0.656885	validation_1-error:0.333333	validation_1-logloss:0.667424
# [52]	validation_0-error:0.302876	validation_0-logloss:0.656426	validation_1-error:0.348485	validation_1-logloss:0.667291
# [53]	validation_0-error:0.302876	validation_0-logloss:0.656183	validation_1-error:0.333333	validation_1-logloss:0.66728
# [54]	validation_0-error:0.306261	validation_0-logloss:0.655869	validation_1-error:0.348485	validation_1-logloss:0.667236
# [55]	validation_0-error:0.309645	validation_0-logloss:0.655273	validation_1-error:0.348485	validation_1-logloss:0.666976
# [56]	validation_0-error:0.311337	validation_0-logloss:0.655061	validation_1-error:0.348485	validation_1-logloss:0.666547
# [57]	validation_0-error:0.309645	validation_0-logloss:0.654822	validation_1-error:0.348485	validation_1-logloss:0.666303
# [58]	validation_0-error:0.306261	validation_0-logloss:0.654062	validation_1-error:0.348485	validation_1-logloss:0.665976
# [59]	validation_0-error:0.304569	validation_0-logloss:0.653781	validation_1-error:0.348485	validation_1-logloss:0.665464
# [60]	validation_0-error:0.306261	validation_0-logloss:0.653375	validation_1-error:0.348485	validation_1-logloss:0.665289
# [61]	validation_0-error:0.302876	validation_0-logloss:0.652751	validation_1-error:0.348485	validation_1-logloss:0.665077
# [62]	validation_0-error:0.304569	validation_0-logloss:0.651749	validation_1-error:0.348485	validation_1-logloss:0.664051
# [63]	validation_0-error:0.302876	validation_0-logloss:0.651193	validation_1-error:0.348485	validation_1-logloss:0.663743
# [64]	validation_0-error:0.307953	validation_0-logloss:0.650729	validation_1-error:0.348485	validation_1-logloss:0.663765
# [65]	validation_0-error:0.307953	validation_0-logloss:0.650237	validation_1-error:0.348485	validation_1-logloss:0.663212
# [66]	validation_0-error:0.304569	validation_0-logloss:0.64964	validation_1-error:0.348485	validation_1-logloss:0.662731
# [67]	validation_0-error:0.2978	validation_0-logloss:0.649174	validation_1-error:0.333333	validation_1-logloss:0.662146
# [68]	validation_0-error:0.301184	validation_0-logloss:0.64893	validation_1-error:0.333333	validation_1-logloss:0.661798
# [69]	validation_0-error:0.302876	validation_0-logloss:0.648675	validation_1-error:0.333333	validation_1-logloss:0.661385
# [70]	validation_0-error:0.299492	validation_0-logloss:0.648139	validation_1-error:0.333333	validation_1-logloss:0.660724
# [71]	validation_0-error:0.299492	validation_0-logloss:0.647855	validation_1-error:0.333333	validation_1-logloss:0.660645
# [72]	validation_0-error:0.301184	validation_0-logloss:0.646992	validation_1-error:0.333333	validation_1-logloss:0.659921
# [73]	validation_0-error:0.301184	validation_0-logloss:0.646976	validation_1-error:0.333333	validation_1-logloss:0.659949
# [74]	validation_0-error:0.301184	validation_0-logloss:0.646691	validation_1-error:0.333333	validation_1-logloss:0.65987
# [75]	validation_0-error:0.302876	validation_0-logloss:0.645805	validation_1-error:0.333333	validation_1-logloss:0.659117
# [76]	validation_0-error:0.299492	validation_0-logloss:0.645155	validation_1-error:0.333333	validation_1-logloss:0.658879
# [77]	validation_0-error:0.301184	validation_0-logloss:0.644921	validation_1-error:0.333333	validation_1-logloss:0.658812
# [78]	validation_0-error:0.301184	validation_0-logloss:0.644883	validation_1-error:0.333333	validation_1-logloss:0.658883
# [79]	validation_0-error:0.302876	validation_0-logloss:0.644578	validation_1-error:0.333333	validation_1-logloss:0.658846
# [80]	validation_0-error:0.306261	validation_0-logloss:0.643918	validation_1-error:0.333333	validation_1-logloss:0.658266
# [81]	validation_0-error:0.304569	validation_0-logloss:0.643305	validation_1-error:0.333333	validation_1-logloss:0.658021
# [82]	validation_0-error:0.301184	validation_0-logloss:0.643024	validation_1-error:0.333333	validation_1-logloss:0.657975
# [83]	validation_0-error:0.306261	validation_0-logloss:0.642798	validation_1-error:0.333333	validation_1-logloss:0.657962
# [84]	validation_0-error:0.302876	validation_0-logloss:0.64216	validation_1-error:0.333333	validation_1-logloss:0.65753
# [85]	validation_0-error:0.304569	validation_0-logloss:0.641687	validation_1-error:0.318182	validation_1-logloss:0.656929
# [86]	validation_0-error:0.306261	validation_0-logloss:0.641105	validation_1-error:0.318182	validation_1-logloss:0.656431
# [87]	validation_0-error:0.306261	validation_0-logloss:0.640851	validation_1-error:0.318182	validation_1-logloss:0.656435
# [88]	validation_0-error:0.306261	validation_0-logloss:0.640344	validation_1-error:0.318182	validation_1-logloss:0.655823
# [89]	validation_0-error:0.306261	validation_0-logloss:0.640334	validation_1-error:0.318182	validation_1-logloss:0.655845
# [90]	validation_0-error:0.307953	validation_0-logloss:0.639955	validation_1-error:0.318182	validation_1-logloss:0.655518
# [91]	validation_0-error:0.309645	validation_0-logloss:0.639465	validation_1-error:0.318182	validation_1-logloss:0.655309
# [92]	validation_0-error:0.307953	validation_0-logloss:0.638993	validation_1-error:0.318182	validation_1-logloss:0.655109
# [93]	validation_0-error:0.309645	validation_0-logloss:0.638417	validation_1-error:0.318182	validation_1-logloss:0.654437
# [94]	validation_0-error:0.306261	validation_0-logloss:0.638211	validation_1-error:0.318182	validation_1-logloss:0.654281
# [95]	validation_0-error:0.306261	validation_0-logloss:0.637666	validation_1-error:0.318182	validation_1-logloss:0.654294
# [96]	validation_0-error:0.304569	validation_0-logloss:0.637475	validation_1-error:0.318182	validation_1-logloss:0.65386
# [97]	validation_0-error:0.306261	validation_0-logloss:0.637279	validation_1-error:0.318182	validation_1-logloss:0.653572
# [98]	validation_0-error:0.306261	validation_0-logloss:0.637064	validation_1-error:0.318182	validation_1-logloss:0.653527
# [99]	validation_0-error:0.302876	validation_0-logloss:0.63668	validation_1-error:0.318182	validation_1-logloss:0.653333
# [100]	validation_0-error:0.302876	validation_0-logloss:0.636073	validation_1-error:0.318182	validation_1-logloss:0.653037
# [101]	validation_0-error:0.302876	validation_0-logloss:0.63607	validation_1-error:0.318182	validation_1-logloss:0.653046
# [102]	validation_0-error:0.304569	validation_0-logloss:0.635856	validation_1-error:0.318182	validation_1-logloss:0.653024
# [103]	validation_0-error:0.302876	validation_0-logloss:0.635631	validation_1-error:0.318182	validation_1-logloss:0.653022
# [104]	validation_0-error:0.302876	validation_0-logloss:0.635287	validation_1-error:0.318182	validation_1-logloss:0.65258
# [105]	validation_0-error:0.301184	validation_0-logloss:0.635054	validation_1-error:0.318182	validation_1-logloss:0.652547
# [106]	validation_0-error:0.301184	validation_0-logloss:0.634874	validation_1-error:0.318182	validation_1-logloss:0.652647
# [107]	validation_0-error:0.299492	validation_0-logloss:0.63438	validation_1-error:0.318182	validation_1-logloss:0.652559
# [108]	validation_0-error:0.294416	validation_0-logloss:0.633779	validation_1-error:0.318182	validation_1-logloss:0.651912
# [109]	validation_0-error:0.291032	validation_0-logloss:0.633357	validation_1-error:0.318182	validation_1-logloss:0.651587
# [110]	validation_0-error:0.28934	validation_0-logloss:0.633347	validation_1-error:0.318182	validation_1-logloss:0.651616
# [111]	validation_0-error:0.28934	validation_0-logloss:0.633163	validation_1-error:0.318182	validation_1-logloss:0.651534
# [112]	validation_0-error:0.28934	validation_0-logloss:0.633144	validation_1-error:0.318182	validation_1-logloss:0.65159
# [113]	validation_0-error:0.28934	validation_0-logloss:0.632751	validation_1-error:0.318182	validation_1-logloss:0.651661
# [114]	validation_0-error:0.28934	validation_0-logloss:0.632736	validation_1-error:0.318182	validation_1-logloss:0.65171
# [115]	validation_0-error:0.291032	validation_0-logloss:0.632251	validation_1-error:0.318182	validation_1-logloss:0.651949
# [116]	validation_0-error:0.294416	validation_0-logloss:0.632045	validation_1-error:0.318182	validation_1-logloss:0.651947
# [117]	validation_0-error:0.294416	validation_0-logloss:0.632036	validation_1-error:0.318182	validation_1-logloss:0.651976
# [118]	validation_0-error:0.292724	validation_0-logloss:0.631802	validation_1-error:0.318182	validation_1-logloss:0.651982
# [119]	validation_0-error:0.292724	validation_0-logloss:0.631399	validation_1-error:0.318182	validation_1-logloss:0.651799
# [120]	validation_0-error:0.294416	validation_0-logloss:0.631387	validation_1-error:0.318182	validation_1-logloss:0.65184
# [121]	validation_0-error:0.292724	validation_0-logloss:0.6308	validation_1-error:0.318182	validation_1-logloss:0.651642
# Stopping. Best iteration:
# [111]	validation_0-error:0.28934	validation_0-logloss:0.633163	validation_1-error:0.318182	validation_1-logloss:0.651534
#
# Accuracy: 68.18%

# %% [markdown]
# ### Display Classification Report of the above model

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

print ('Accuracy:', accuracy_score(y_test_m, predictions_mexp_train))
print ('F1 score:', f1_score(y_test_m, predictions_mexp_test))
print ('Recall:', recall_score(y_test_m, predictions_mexp_test))
print ('Precision:', precision_score(y_test_m, predictions_mexp_test))
print ('\n clasification report:\n', classification_report(y_test_m,predictions_mexp_test))
print ('\n confussion matrix:\n',confusion_matrix(y_test_m, predictions_mexp_train))
# Out:
# Accuracy: 0.6818181818181818
# F1 score: 0.5882352941176471
# Recall: 0.4411764705882353
# Precision: 0.8823529411764706
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74        32
#            1       0.88      0.44      0.59        34
#
#    micro avg       0.68      0.68      0.68        66
#    macro avg       0.75      0.69      0.66        66
# weighted avg       0.75      0.68      0.66        66
#
#
#  confussion matrix:
#  [[30  2]
#  [19 15]]

# %% [markdown]
# ## Manually tuning hyper-parameters and assigning weights to different modalities during Late Fusion

# %% [markdown]
# ### COMBINE MEXP+GAZE+AUDIO

# %%
h_a=0.5
h_m=0.5
h_g=0.3

y_pred_a = model_a.predict(X_test_a)
y_pred_m = model_m.predict(X_test_m)
y_pred_g = model_g.predict(X_test_g)

final_pred= h_a*y_pred_a + h_m*y_pred_m + h_g*y_pred_g
final_pred = [round(value) for value in final_pred]
if(y_test_m==y_test_a):
    if(y_test_a==y_test_g):
        y_test=y_test_a
print ('Accuracy:', accuracy_score(y_test, final_pred))
print ('F1 score:', f1_score(y_test, final_pred))
print ('Recall:', recall_score(y_test, final_pred))
print ('Precision:', precision_score(y_test, final_pred))
print ('\n clasification report:\n', classification_report(y_test,final_pred))
print ('\n confussion matrix:\n',confusion_matrix(y_test, final_pred))
# Out:
# Accuracy: 0.6212121212121212
# F1 score: 0.4444444444444445
# Recall: 0.29411764705882354
# Precision: 0.9090909090909091
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.97      0.71        32
#            1       0.91      0.29      0.44        34
#
#    micro avg       0.62      0.62      0.62        66
#    macro avg       0.74      0.63      0.58        66
# weighted avg       0.74      0.62      0.57        66
#
#
#  confussion matrix:
#  [[31  1]
#  [24 10]]

# %% [markdown]
# ### COMBINE MEXP+GAZE

# %%
h_m=0.7
h_g=0.1

y_pred_m = model_m.predict(X_test_m)
y_pred_g = model_g.predict(X_test_g)

final_pred= h_m*y_pred_m + h_g*y_pred_g
final_pred = [round(value) for value in final_pred]
if(y_test_m==y_test_g):
        y_test=y_test_g
print ('Accuracy:', accuracy_score(y_test, final_pred))
print ('F1 score:', f1_score(y_test, final_pred))
print ('Recall:', recall_score(y_test, final_pred))
print ('Precision:', precision_score(y_test, final_pred))
print ('\n clasification report:\n', classification_report(y_test,final_pred))
print ('\n confussion matrix:\n',confusion_matrix(y_test, final_pred))
# Out:
# Accuracy: 0.6818181818181818
# F1 score: 0.5882352941176471
# Recall: 0.4411764705882353
# Precision: 0.8823529411764706
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74        32
#            1       0.88      0.44      0.59        34
#
#    micro avg       0.68      0.68      0.68        66
#    macro avg       0.75      0.69      0.66        66
# weighted avg       0.75      0.68      0.66        66
#
#
#  confussion matrix:
#  [[30  2]
#  [19 15]]

# %% [markdown]
# ### COMBINE GAZE+AUDIO

# %%
h_a=0.8
h_g=0.4

y_pred_a = model_a.predict(X_test_a)
y_pred_g = model_g.predict(X_test_g)

final_pred= h_a*y_pred_a + h_g*y_pred_g
final_pred = [round(value) for value in final_pred]

if(y_test_a==y_test_g):
    y_test=y_test_a
print ('Accuracy:', accuracy_score(y_test, final_pred))
print ('F1 score:', f1_score(y_test, final_pred))
print ('Recall:', recall_score(y_test, final_pred))
print ('Precision:', precision_score(y_test, final_pred))
print ('\n clasification report:\n', classification_report(y_test,final_pred))
print ('\n confussion matrix:\n',confusion_matrix(y_test, final_pred))
# Out:
# Accuracy: 0.6818181818181818
# F1 score: 0.5882352941176471
# Recall: 0.4411764705882353
# Precision: 0.8823529411764706
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74        32
#            1       0.88      0.44      0.59        34
#
#    micro avg       0.68      0.68      0.68        66
#    macro avg       0.75      0.69      0.66        66
# weighted avg       0.75      0.68      0.66        66
#
#
#  confussion matrix:
#  [[30  2]
#  [19 15]]

# %% [markdown]
# ### COMBINE MEXP+AUDIO

# %%
h_a=0.5
h_m=0.6

y_pred_a = model_a.predict(X_test_a)
y_pred_m = model_m.predict(X_test_m)

final_pred= h_a*y_pred_a + h_m*y_pred_m
final_pred = [round(value) for value in final_pred]
if(y_test_m==y_test_a):
        y_test=y_test_a
print ('Accuracy:', accuracy_score(y_test, final_pred))
print ('F1 score:', f1_score(y_test, final_pred))
print ('Recall:', recall_score(y_test, final_pred))
print ('Precision:', precision_score(y_test, final_pred))
print ('\n clasification report:\n', classification_report(y_test,final_pred))
print ('\n confussion matrix:\n',confusion_matrix(y_test, final_pred))
# Out:
# Accuracy: 0.6818181818181818
# F1 score: 0.5882352941176471
# Recall: 0.4411764705882353
# Precision: 0.8823529411764706
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74        32
#            1       0.88      0.44      0.59        34
#
#    micro avg       0.68      0.68      0.68        66
#    macro avg       0.75      0.69      0.66        66
# weighted avg       0.75      0.68      0.66        66
#
#
#  confussion matrix:
#  [[30  2]
#  [19 15]]

# %% [markdown]
# ## Using Classifier model to vote for the best Modality
#
# Predicted outputs from individual models are further processed by another XGBClassifier

# %%
y_pred_a_test = model_a.predict(X_test_a)
y_pred_m_test = model_m.predict(X_test_m)
y_pred_g_test = model_g.predict(X_test_g)
y_pred_a_train = model_a.predict(X_train_a)
y_pred_m_train = model_m.predict(X_train_m)
y_pred_g_train = model_g.predict(X_train_g)
dfObj1 = pd.DataFrame(y_pred_a_train,columns = ['Audio'] )
dfObj2=pd.DataFrame(y_pred_m_train,columns = ['Mexp']) 
dfObj3=pd.DataFrame(y_pred_g_train,columns = ['Gaze'])
dfObj4 = pd.DataFrame(y_pred_a_test,columns = ['Audio']) 
dfObj5=pd.DataFrame(y_pred_m_test,columns = ['Mexp']) 
dfObj6=pd.DataFrame(y_pred_g_test,columns = ['Gaze'])
df_train_data = pd.concat([dfObj1, dfObj2, dfObj3], axis=1)
df_test_data = pd.concat([dfObj4, dfObj5, dfObj6], axis=1)
if(y_test_m==y_test_a):
    if(y_test_a==y_test_g):
        y_test=y_test_a
if(y_train_m==y_train_a):
    if(y_train_a==y_train_g):
        y_train=y_train_a
model = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=3, 
                      gamma=10)
eval_set = [(df_train_data, y_train), (df_test_data, y_test)]
model.fit(df_train_data, y_train, eval_metric=["error", "logloss"], eval_set=eval_set,early_stopping_rounds=10, verbose=True)
y_pred=model.predict(df_test_data)
final_pred=[round(value) for value in y_pred]
print ('Accuracy:', accuracy_score(y_test, final_pred))
print ('F1 score:', f1_score(y_test, final_pred))
print ('Recall:', recall_score(y_test, final_pred))
print ('Precision:', precision_score(y_test, final_pred))
print ('\n clasification report:\n', classification_report(y_test,final_pred))
print ('\n confussion matrix:\n',confusion_matrix(y_test, final_pred))
# Out:
# [0]	validation_0-error:0.174281	validation_0-logloss:0.688917	validation_1-error:0.318182	validation_1-logloss:0.690711
# Multiple eval metrics have been passed: 'validation_1-logloss' will be used for early stopping.
#
# Will train until validation_1-logloss hasn't improved in 10 rounds.
# [1]	validation_0-error:0.174281	validation_0-logloss:0.687758	validation_1-error:0.318182	validation_1-logloss:0.690089
# [2]	validation_0-error:0.191201	validation_0-logloss:0.686626	validation_1-error:0.333333	validation_1-logloss:0.689501
# [3]	validation_0-error:0.174281	validation_0-logloss:0.682461	validation_1-error:0.318182	validation_1-logloss:0.68711
# [4]	validation_0-error:0.191201	validation_0-logloss:0.681263	validation_1-error:0.333333	validation_1-logloss:0.686489
# [5]	validation_0-error:0.174281	validation_0-logloss:0.677236	validation_1-error:0.318182	validation_1-logloss:0.684195
# [6]	validation_0-error:0.174281	validation_0-logloss:0.67333	validation_1-error:0.318182	validation_1-logloss:0.681996
# [7]	validation_0-error:0.174281	validation_0-logloss:0.671751	validation_1-error:0.318182	validation_1-logloss:0.680463
# [8]	validation_0-error:0.177665	validation_0-logloss:0.670675	validation_1-error:0.318182	validation_1-logloss:0.679935
# [9]	validation_0-error:0.174281	validation_0-logloss:0.666956	validation_1-error:0.318182	validation_1-logloss:0.677867
# [10]	validation_0-error:0.177665	validation_0-logloss:0.665988	validation_1-error:0.318182	validation_1-logloss:0.67737
# [11]	validation_0-error:0.191201	validation_0-logloss:0.664906	validation_1-error:0.333333	validation_1-logloss:0.676835
# [12]	validation_0-error:0.191201	validation_0-logloss:0.663822	validation_1-error:0.333333	validation_1-logloss:0.676281
# [13]	validation_0-error:0.191201	validation_0-logloss:0.659963	validation_1-error:0.333333	validation_1-logloss:0.674135
# [14]	validation_0-error:0.177665	validation_0-logloss:0.658467	validation_1-error:0.318182	validation_1-logloss:0.672702
# [15]	validation_0-error:0.177665	validation_0-logloss:0.656913	validation_1-error:0.318182	validation_1-logloss:0.671226
# [16]	validation_0-error:0.177665	validation_0-logloss:0.653449	validation_1-error:0.318182	validation_1-logloss:0.669326
# [17]	validation_0-error:0.177665	validation_0-logloss:0.65249	validation_1-error:0.318182	validation_1-logloss:0.668884
# [18]	validation_0-error:0.177665	validation_0-logloss:0.651601	validation_1-error:0.318182	validation_1-logloss:0.668478
# [19]	validation_0-error:0.191201	validation_0-logloss:0.650733	validation_1-error:0.333333	validation_1-logloss:0.66807
# [20]	validation_0-error:0.191201	validation_0-logloss:0.649283	validation_1-error:0.333333	validation_1-logloss:0.666727
# [21]	validation_0-error:0.177665	validation_0-logloss:0.645751	validation_1-error:0.318182	validation_1-logloss:0.664811
# [22]	validation_0-error:0.177665	validation_0-logloss:0.642469	validation_1-error:0.318182	validation_1-logloss:0.663038
# [23]	validation_0-error:0.177665	validation_0-logloss:0.641147	validation_1-error:0.318182	validation_1-logloss:0.661803
# [24]	validation_0-error:0.177665	validation_0-logloss:0.639857	validation_1-error:0.318182	validation_1-logloss:0.660591
# [25]	validation_0-error:0.177665	validation_0-logloss:0.638918	validation_1-error:0.318182	validation_1-logloss:0.660184
# [26]	validation_0-error:0.177665	validation_0-logloss:0.638162	validation_1-error:0.318182	validation_1-logloss:0.659839
# [27]	validation_0-error:0.177665	validation_0-logloss:0.635149	validation_1-error:0.318182	validation_1-logloss:0.658231
# [28]	validation_0-error:0.177665	validation_0-logloss:0.631893	validation_1-error:0.318182	validation_1-logloss:0.656538
# [29]	validation_0-error:0.177665	validation_0-logloss:0.630591	validation_1-error:0.318182	validation_1-logloss:0.655306
# [30]	validation_0-error:0.177665	validation_0-logloss:0.629846	validation_1-error:0.318182	validation_1-logloss:0.654987
# [31]	validation_0-error:0.177665	validation_0-logloss:0.628452	validation_1-error:0.318182	validation_1-logloss:0.653679
# [32]	validation_0-error:0.177665	validation_0-logloss:0.627753	validation_1-error:0.318182	validation_1-logloss:0.653389
# [33]	validation_0-error:0.177665	validation_0-logloss:0.626998	validation_1-error:0.318182	validation_1-logloss:0.653078
# [34]	validation_0-error:0.177665	validation_0-logloss:0.626342	validation_1-error:0.318182	validation_1-logloss:0.652784
# [35]	validation_0-error:0.177665	validation_0-logloss:0.625093	validation_1-error:0.318182	validation_1-logloss:0.651626
# [36]	validation_0-error:0.177665	validation_0-logloss:0.622028	validation_1-error:0.318182	validation_1-logloss:0.65007
# [37]	validation_0-error:0.177665	validation_0-logloss:0.62078	validation_1-error:0.318182	validation_1-logloss:0.648861
# [38]	validation_0-error:0.177665	validation_0-logloss:0.620084	validation_1-error:0.318182	validation_1-logloss:0.648603
# [39]	validation_0-error:0.177665	validation_0-logloss:0.618952	validation_1-error:0.318182	validation_1-logloss:0.647547
# [40]	validation_0-error:0.177665	validation_0-logloss:0.617896	validation_1-error:0.318182	validation_1-logloss:0.646515
# [41]	validation_0-error:0.177665	validation_0-logloss:0.617294	validation_1-error:0.318182	validation_1-logloss:0.646288
# [42]	validation_0-error:0.177665	validation_0-logloss:0.616153	validation_1-error:0.318182	validation_1-logloss:0.645212
# [43]	validation_0-error:0.177665	validation_0-logloss:0.615113	validation_1-error:0.318182	validation_1-logloss:0.644252
# [44]	validation_0-error:0.177665	validation_0-logloss:0.612211	validation_1-error:0.318182	validation_1-logloss:0.642747
# [45]	validation_0-error:0.177665	validation_0-logloss:0.611088	validation_1-error:0.318182	validation_1-logloss:0.641713
# [46]	validation_0-error:0.177665	validation_0-logloss:0.610132	validation_1-error:0.318182	validation_1-logloss:0.640809
# [47]	validation_0-error:0.177665	validation_0-logloss:0.607232	validation_1-error:0.318182	validation_1-logloss:0.639328
# [48]	validation_0-error:0.177665	validation_0-logloss:0.606297	validation_1-error:0.318182	validation_1-logloss:0.638438
# [49]	validation_0-error:0.177665	validation_0-logloss:0.603615	validation_1-error:0.318182	validation_1-logloss:0.637098
# [50]	validation_0-error:0.177665	validation_0-logloss:0.602672	validation_1-error:0.318182	validation_1-logloss:0.636176
# [51]	validation_0-error:0.177665	validation_0-logloss:0.599904	validation_1-error:0.318182	validation_1-logloss:0.634771
# [52]	validation_0-error:0.177665	validation_0-logloss:0.599009	validation_1-error:0.318182	validation_1-logloss:0.633923
# [53]	validation_0-error:0.177665	validation_0-logloss:0.598456	validation_1-error:0.318182	validation_1-logloss:0.633712
# [54]	validation_0-error:0.177665	validation_0-logloss:0.595857	validation_1-error:0.318182	validation_1-logloss:0.632448
# [55]	validation_0-error:0.177665	validation_0-logloss:0.595315	validation_1-error:0.318182	validation_1-logloss:0.632264
# [56]	validation_0-error:0.177665	validation_0-logloss:0.594796	validation_1-error:0.318182	validation_1-logloss:0.632084
# [57]	validation_0-error:0.177665	validation_0-logloss:0.593815	validation_1-error:0.318182	validation_1-logloss:0.631143
# [58]	validation_0-error:0.177665	validation_0-logloss:0.592892	validation_1-error:0.318182	validation_1-logloss:0.630323
# [59]	validation_0-error:0.177665	validation_0-logloss:0.590335	validation_1-error:0.318182	validation_1-logloss:0.629099
# [60]	validation_0-error:0.177665	validation_0-logloss:0.587897	validation_1-error:0.318182	validation_1-logloss:0.627926
# [61]	validation_0-error:0.177665	validation_0-logloss:0.587078	validation_1-error:0.318182	validation_1-logloss:0.627094
# [62]	validation_0-error:0.177665	validation_0-logloss:0.584492	validation_1-error:0.318182	validation_1-logloss:0.625889
# [63]	validation_0-error:0.177665	validation_0-logloss:0.583631	validation_1-error:0.318182	validation_1-logloss:0.62509
# [64]	validation_0-error:0.177665	validation_0-logloss:0.581178	validation_1-error:0.318182	validation_1-logloss:0.623926
# [65]	validation_0-error:0.177665	validation_0-logloss:0.580434	validation_1-error:0.318182	validation_1-logloss:0.623199
# [66]	validation_0-error:0.177665	validation_0-logloss:0.580082	validation_1-error:0.318182	validation_1-logloss:0.623093
# [67]	validation_0-error:0.177665	validation_0-logloss:0.57973	validation_1-error:0.318182	validation_1-logloss:0.623005
# [68]	validation_0-error:0.177665	validation_0-logloss:0.577331	validation_1-error:0.318182	validation_1-logloss:0.621907
# [69]	validation_0-error:0.177665	validation_0-logloss:0.575004	validation_1-error:0.318182	validation_1-logloss:0.62084
# [70]	validation_0-error:0.177665	validation_0-logloss:0.574297	validation_1-error:0.318182	validation_1-logloss:0.620168
# [71]	validation_0-error:0.177665	validation_0-logloss:0.573863	validation_1-error:0.318182	validation_1-logloss:0.620076
# [72]	validation_0-error:0.177665	validation_0-logloss:0.571569	validation_1-error:0.318182	validation_1-logloss:0.619046
# [73]	validation_0-error:0.177665	validation_0-logloss:0.57117	validation_1-error:0.318182	validation_1-logloss:0.618932
# [74]	validation_0-error:0.177665	validation_0-logloss:0.569004	validation_1-error:0.318182	validation_1-logloss:0.617946
# [75]	validation_0-error:0.177665	validation_0-logloss:0.568335	validation_1-error:0.318182	validation_1-logloss:0.617256
# [76]	validation_0-error:0.177665	validation_0-logloss:0.56608	validation_1-error:0.318182	validation_1-logloss:0.61625
# [77]	validation_0-error:0.177665	validation_0-logloss:0.56577	validation_1-error:0.318182	validation_1-logloss:0.616199
# [78]	validation_0-error:0.177665	validation_0-logloss:0.565058	validation_1-error:0.318182	validation_1-logloss:0.615542
# [79]	validation_0-error:0.177665	validation_0-logloss:0.562879	validation_1-error:0.318182	validation_1-logloss:0.614583
# [80]	validation_0-error:0.177665	validation_0-logloss:0.562526	validation_1-error:0.318182	validation_1-logloss:0.614514
# [81]	validation_0-error:0.177665	validation_0-logloss:0.561821	validation_1-error:0.318182	validation_1-logloss:0.613865
# [82]	validation_0-error:0.177665	validation_0-logloss:0.55981	validation_1-error:0.318182	validation_1-logloss:0.613006
# [83]	validation_0-error:0.177665	validation_0-logloss:0.559156	validation_1-error:0.318182	validation_1-logloss:0.612385
# [84]	validation_0-error:0.177665	validation_0-logloss:0.558499	validation_1-error:0.318182	validation_1-logloss:0.611687
# [85]	validation_0-error:0.177665	validation_0-logloss:0.557917	validation_1-error:0.318182	validation_1-logloss:0.611176
# [86]	validation_0-error:0.177665	validation_0-logloss:0.555994	validation_1-error:0.318182	validation_1-logloss:0.610337
# [87]	validation_0-error:0.177665	validation_0-logloss:0.555439	validation_1-error:0.318182	validation_1-logloss:0.609855
# [88]	validation_0-error:0.177665	validation_0-logloss:0.553494	validation_1-error:0.318182	validation_1-logloss:0.609062
# [89]	validation_0-error:0.177665	validation_0-logloss:0.551682	validation_1-error:0.318182	validation_1-logloss:0.608296
# [90]	validation_0-error:0.177665	validation_0-logloss:0.551156	validation_1-error:0.318182	validation_1-logloss:0.607791
# [91]	validation_0-error:0.177665	validation_0-logloss:0.549374	validation_1-error:0.318182	validation_1-logloss:0.607047
# [92]	validation_0-error:0.177665	validation_0-logloss:0.549069	validation_1-error:0.318182	validation_1-logloss:0.607009
# [93]	validation_0-error:0.177665	validation_0-logloss:0.548794	validation_1-error:0.318182	validation_1-logloss:0.606985
# [94]	validation_0-error:0.177665	validation_0-logloss:0.548203	validation_1-error:0.318182	validation_1-logloss:0.606404
# [95]	validation_0-error:0.177665	validation_0-logloss:0.548183	validation_1-error:0.318182	validation_1-logloss:0.60647
# [96]	validation_0-error:0.177665	validation_0-logloss:0.546469	validation_1-error:0.318182	validation_1-logloss:0.605785
# [97]	validation_0-error:0.177665	validation_0-logloss:0.544656	validation_1-error:0.318182	validation_1-logloss:0.605054
# [98]	validation_0-error:0.177665	validation_0-logloss:0.54465	validation_1-error:0.318182	validation_1-logloss:0.605072
# [99]	validation_0-error:0.177665	validation_0-logloss:0.542859	validation_1-error:0.318182	validation_1-logloss:0.604348
# [100]	validation_0-error:0.177665	validation_0-logloss:0.542618	validation_1-error:0.318182	validation_1-logloss:0.604318
# [101]	validation_0-error:0.177665	validation_0-logloss:0.542125	validation_1-error:0.318182	validation_1-logloss:0.603817
# [102]	validation_0-error:0.177665	validation_0-logloss:0.541621	validation_1-error:0.318182	validation_1-logloss:0.60333
# [103]	validation_0-error:0.177665	validation_0-logloss:0.54106	validation_1-error:0.318182	validation_1-logloss:0.602798
# [104]	validation_0-error:0.177665	validation_0-logloss:0.539351	validation_1-error:0.318182	validation_1-logloss:0.602145
# [105]	validation_0-error:0.177665	validation_0-logloss:0.539345	validation_1-error:0.318182	validation_1-logloss:0.602165
# [106]	validation_0-error:0.177665	validation_0-logloss:0.537725	validation_1-error:0.318182	validation_1-logloss:0.601535
# [107]	validation_0-error:0.177665	validation_0-logloss:0.537246	validation_1-error:0.318182	validation_1-logloss:0.601089
# [108]	validation_0-error:0.177665	validation_0-logloss:0.536742	validation_1-error:0.318182	validation_1-logloss:0.600601
# [109]	validation_0-error:0.177665	validation_0-logloss:0.536318	validation_1-error:0.318182	validation_1-logloss:0.600256
# [110]	validation_0-error:0.177665	validation_0-logloss:0.534624	validation_1-error:0.318182	validation_1-logloss:0.599597
# [111]	validation_0-error:0.177665	validation_0-logloss:0.534617	validation_1-error:0.318182	validation_1-logloss:0.599625
# [112]	validation_0-error:0.177665	validation_0-logloss:0.534198	validation_1-error:0.318182	validation_1-logloss:0.599268
# [113]	validation_0-error:0.177665	validation_0-logloss:0.532607	validation_1-error:0.318182	validation_1-logloss:0.598681
# [114]	validation_0-error:0.177665	validation_0-logloss:0.532216	validation_1-error:0.318182	validation_1-logloss:0.598315
# [115]	validation_0-error:0.177665	validation_0-logloss:0.530708	validation_1-error:0.318182	validation_1-logloss:0.597761
# [116]	validation_0-error:0.177665	validation_0-logloss:0.530704	validation_1-error:0.318182	validation_1-logloss:0.597779
# [117]	validation_0-error:0.177665	validation_0-logloss:0.530297	validation_1-error:0.318182	validation_1-logloss:0.597398
# [118]	validation_0-error:0.177665	validation_0-logloss:0.53028	validation_1-error:0.318182	validation_1-logloss:0.597477
# [119]	validation_0-error:0.177665	validation_0-logloss:0.530275	validation_1-error:0.318182	validation_1-logloss:0.597501
# [120]	validation_0-error:0.177665	validation_0-logloss:0.52982	validation_1-error:0.318182	validation_1-logloss:0.597078
# [121]	validation_0-error:0.177665	validation_0-logloss:0.529597	validation_1-error:0.318182	validation_1-logloss:0.597053
# [122]	validation_0-error:0.177665	validation_0-logloss:0.528059	validation_1-error:0.318182	validation_1-logloss:0.596506
# [123]	validation_0-error:0.177665	validation_0-logloss:0.528054	validation_1-error:0.318182	validation_1-logloss:0.596532
# [124]	validation_0-error:0.177665	validation_0-logloss:0.527796	validation_1-error:0.318182	validation_1-logloss:0.596526
# [125]	validation_0-error:0.177665	validation_0-logloss:0.527348	validation_1-error:0.318182	validation_1-logloss:0.596037
# [126]	validation_0-error:0.177665	validation_0-logloss:0.526957	validation_1-error:0.318182	validation_1-logloss:0.59575
# [127]	validation_0-error:0.177665	validation_0-logloss:0.526533	validation_1-error:0.318182	validation_1-logloss:0.595343
# [128]	validation_0-error:0.177665	validation_0-logloss:0.525016	validation_1-error:0.318182	validation_1-logloss:0.594832
# [129]	validation_0-error:0.177665	validation_0-logloss:0.523474	validation_1-error:0.318182	validation_1-logloss:0.594302
# [130]	validation_0-error:0.177665	validation_0-logloss:0.522033	validation_1-error:0.318182	validation_1-logloss:0.593815
# [131]	validation_0-error:0.177665	validation_0-logloss:0.5217	validation_1-error:0.318182	validation_1-logloss:0.59344
# [132]	validation_0-error:0.177665	validation_0-logloss:0.521683	validation_1-error:0.318182	validation_1-logloss:0.593538
# [133]	validation_0-error:0.177665	validation_0-logloss:0.520218	validation_1-error:0.318182	validation_1-logloss:0.59303
# [134]	validation_0-error:0.177665	validation_0-logloss:0.518926	validation_1-error:0.318182	validation_1-logloss:0.592556
# [135]	validation_0-error:0.177665	validation_0-logloss:0.518509	validation_1-error:0.318182	validation_1-logloss:0.592102
# [136]	validation_0-error:0.177665	validation_0-logloss:0.518105	validation_1-error:0.318182	validation_1-logloss:0.591719
# [137]	validation_0-error:0.177665	validation_0-logloss:0.51809	validation_1-error:0.318182	validation_1-logloss:0.591817
# [138]	validation_0-error:0.177665	validation_0-logloss:0.517715	validation_1-error:0.318182	validation_1-logloss:0.591441
# [139]	validation_0-error:0.177665	validation_0-logloss:0.516353	validation_1-error:0.318182	validation_1-logloss:0.591008
# [140]	validation_0-error:0.177665	validation_0-logloss:0.51502	validation_1-error:0.318182	validation_1-logloss:0.590574
# [141]	validation_0-error:0.177665	validation_0-logloss:0.51469	validation_1-error:0.318182	validation_1-logloss:0.590226
# [142]	validation_0-error:0.177665	validation_0-logloss:0.514381	validation_1-error:0.318182	validation_1-logloss:0.589895
# [143]	validation_0-error:0.177665	validation_0-logloss:0.513016	validation_1-error:0.318182	validation_1-logloss:0.589444
# [144]	validation_0-error:0.177665	validation_0-logloss:0.513018	validation_1-error:0.318182	validation_1-logloss:0.589427
# [145]	validation_0-error:0.177665	validation_0-logloss:0.512711	validation_1-error:0.318182	validation_1-logloss:0.589156
# [146]	validation_0-error:0.177665	validation_0-logloss:0.51243	validation_1-error:0.318182	validation_1-logloss:0.588841
# [147]	validation_0-error:0.177665	validation_0-logloss:0.512429	validation_1-error:0.318182	validation_1-logloss:0.588846
# [148]	validation_0-error:0.177665	validation_0-logloss:0.512425	validation_1-error:0.318182	validation_1-logloss:0.588876
# [149]	validation_0-error:0.177665	validation_0-logloss:0.511153	validation_1-error:0.318182	validation_1-logloss:0.588484
# [150]	validation_0-error:0.177665	validation_0-logloss:0.511148	validation_1-error:0.318182	validation_1-logloss:0.588519
# [151]	validation_0-error:0.177665	validation_0-logloss:0.51114	validation_1-error:0.318182	validation_1-logloss:0.588576
# [152]	validation_0-error:0.177665	validation_0-logloss:0.510859	validation_1-error:0.318182	validation_1-logloss:0.588285
# [153]	validation_0-error:0.177665	validation_0-logloss:0.51057	validation_1-error:0.318182	validation_1-logloss:0.588044
# [154]	validation_0-error:0.177665	validation_0-logloss:0.510564	validation_1-error:0.318182	validation_1-logloss:0.588093
# [155]	validation_0-error:0.177665	validation_0-logloss:0.509335	validation_1-error:0.318182	validation_1-logloss:0.587739
# [156]	validation_0-error:0.177665	validation_0-logloss:0.509035	validation_1-error:0.318182	validation_1-logloss:0.587402
# [157]	validation_0-error:0.177665	validation_0-logloss:0.507822	validation_1-error:0.318182	validation_1-logloss:0.587026
# [158]	validation_0-error:0.177665	validation_0-logloss:0.507567	validation_1-error:0.318182	validation_1-logloss:0.586779
# [159]	validation_0-error:0.177665	validation_0-logloss:0.507568	validation_1-error:0.318182	validation_1-logloss:0.586767
# [160]	validation_0-error:0.177665	validation_0-logloss:0.506348	validation_1-error:0.318182	validation_1-logloss:0.586367
# [161]	validation_0-error:0.177665	validation_0-logloss:0.506347	validation_1-error:0.318182	validation_1-logloss:0.586372
# [162]	validation_0-error:0.177665	validation_0-logloss:0.506067	validation_1-error:0.318182	validation_1-logloss:0.586058
# [163]	validation_0-error:0.177665	validation_0-logloss:0.504829	validation_1-error:0.318182	validation_1-logloss:0.585746
# [164]	validation_0-error:0.177665	validation_0-logloss:0.503694	validation_1-error:0.318182	validation_1-logloss:0.585423
# [165]	validation_0-error:0.177665	validation_0-logloss:0.502612	validation_1-error:0.318182	validation_1-logloss:0.585102
# [166]	validation_0-error:0.177665	validation_0-logloss:0.502609	validation_1-error:0.318182	validation_1-logloss:0.58513
# [167]	validation_0-error:0.177665	validation_0-logloss:0.50148	validation_1-error:0.318182	validation_1-logloss:0.584885
# [168]	validation_0-error:0.177665	validation_0-logloss:0.501479	validation_1-error:0.318182	validation_1-logloss:0.584893
# [169]	validation_0-error:0.177665	validation_0-logloss:0.5004	validation_1-error:0.318182	validation_1-logloss:0.584603
# [170]	validation_0-error:0.177665	validation_0-logloss:0.500396	validation_1-error:0.318182	validation_1-logloss:0.584642
# [171]	validation_0-error:0.177665	validation_0-logloss:0.499299	validation_1-error:0.318182	validation_1-logloss:0.584387
# [172]	validation_0-error:0.177665	validation_0-logloss:0.499288	validation_1-error:0.318182	validation_1-logloss:0.584491
# [173]	validation_0-error:0.177665	validation_0-logloss:0.499049	validation_1-error:0.318182	validation_1-logloss:0.584245
# [174]	validation_0-error:0.177665	validation_0-logloss:0.498047	validation_1-error:0.318182	validation_1-logloss:0.584003
# [175]	validation_0-error:0.177665	validation_0-logloss:0.496997	validation_1-error:0.318182	validation_1-logloss:0.583779
# [176]	validation_0-error:0.177665	validation_0-logloss:0.496756	validation_1-error:0.318182	validation_1-logloss:0.583602
# [177]	validation_0-error:0.177665	validation_0-logloss:0.496752	validation_1-error:0.318182	validation_1-logloss:0.58364
# [178]	validation_0-error:0.177665	validation_0-logloss:0.496493	validation_1-error:0.318182	validation_1-logloss:0.583353
# [179]	validation_0-error:0.177665	validation_0-logloss:0.495506	validation_1-error:0.318182	validation_1-logloss:0.583121
# [180]	validation_0-error:0.177665	validation_0-logloss:0.494471	validation_1-error:0.318182	validation_1-logloss:0.582854
# [181]	validation_0-error:0.177665	validation_0-logloss:0.49447	validation_1-error:0.318182	validation_1-logloss:0.582864
# [182]	validation_0-error:0.177665	validation_0-logloss:0.494461	validation_1-error:0.318182	validation_1-logloss:0.582963
# [183]	validation_0-error:0.177665	validation_0-logloss:0.494242	validation_1-error:0.318182	validation_1-logloss:0.582721
# [184]	validation_0-error:0.177665	validation_0-logloss:0.493239	validation_1-error:0.318182	validation_1-logloss:0.582493
# [185]	validation_0-error:0.177665	validation_0-logloss:0.492229	validation_1-error:0.318182	validation_1-logloss:0.582241
# [186]	validation_0-error:0.177665	validation_0-logloss:0.491271	validation_1-error:0.318182	validation_1-logloss:0.582022
# [187]	validation_0-error:0.177665	validation_0-logloss:0.491271	validation_1-error:0.318182	validation_1-logloss:0.582021
# [188]	validation_0-error:0.177665	validation_0-logloss:0.491266	validation_1-error:0.318182	validation_1-logloss:0.58209
# [189]	validation_0-error:0.177665	validation_0-logloss:0.491266	validation_1-error:0.318182	validation_1-logloss:0.582085
# [190]	validation_0-error:0.177665	validation_0-logloss:0.490297	validation_1-error:0.318182	validation_1-logloss:0.581881
# [191]	validation_0-error:0.177665	validation_0-logloss:0.490293	validation_1-error:0.318182	validation_1-logloss:0.58193
# [192]	validation_0-error:0.177665	validation_0-logloss:0.490291	validation_1-error:0.318182	validation_1-logloss:0.581948
# [193]	validation_0-error:0.177665	validation_0-logloss:0.489381	validation_1-error:0.318182	validation_1-logloss:0.581735
# [194]	validation_0-error:0.177665	validation_0-logloss:0.489378	validation_1-error:0.318182	validation_1-logloss:0.58177
# [195]	validation_0-error:0.177665	validation_0-logloss:0.48938	validation_1-error:0.318182	validation_1-logloss:0.581753
# [196]	validation_0-error:0.177665	validation_0-logloss:0.489374	validation_1-error:0.318182	validation_1-logloss:0.581822
# [197]	validation_0-error:0.177665	validation_0-logloss:0.488458	validation_1-error:0.318182	validation_1-logloss:0.581625
# [198]	validation_0-error:0.177665	validation_0-logloss:0.488455	validation_1-error:0.318182	validation_1-logloss:0.581659
# [199]	validation_0-error:0.177665	validation_0-logloss:0.488455	validation_1-error:0.318182	validation_1-logloss:0.581659
# [200]	validation_0-error:0.177665	validation_0-logloss:0.48845	validation_1-error:0.318182	validation_1-logloss:0.581726
# [201]	validation_0-error:0.177665	validation_0-logloss:0.488223	validation_1-error:0.318182	validation_1-logloss:0.581495
# [202]	validation_0-error:0.177665	validation_0-logloss:0.488221	validation_1-error:0.318182	validation_1-logloss:0.581533
# [203]	validation_0-error:0.177665	validation_0-logloss:0.488221	validation_1-error:0.318182	validation_1-logloss:0.581529
# [204]	validation_0-error:0.177665	validation_0-logloss:0.487394	validation_1-error:0.318182	validation_1-logloss:0.581355
# [205]	validation_0-error:0.177665	validation_0-logloss:0.486469	validation_1-error:0.318182	validation_1-logloss:0.581254
# [206]	validation_0-error:0.177665	validation_0-logloss:0.485653	validation_1-error:0.318182	validation_1-logloss:0.581107
# [207]	validation_0-error:0.177665	validation_0-logloss:0.484827	validation_1-error:0.318182	validation_1-logloss:0.580936
# [208]	validation_0-error:0.177665	validation_0-logloss:0.484825	validation_1-error:0.318182	validation_1-logloss:0.580965
# [209]	validation_0-error:0.177665	validation_0-logloss:0.484822	validation_1-error:0.318182	validation_1-logloss:0.581019
# [210]	validation_0-error:0.177665	validation_0-logloss:0.484819	validation_1-error:0.318182	validation_1-logloss:0.581059
# [211]	validation_0-error:0.177665	validation_0-logloss:0.484813	validation_1-error:0.318182	validation_1-logloss:0.581156
# [212]	validation_0-error:0.177665	validation_0-logloss:0.484603	validation_1-error:0.318182	validation_1-logloss:0.580871
# [213]	validation_0-error:0.177665	validation_0-logloss:0.483755	validation_1-error:0.318182	validation_1-logloss:0.580739
# [214]	validation_0-error:0.177665	validation_0-logloss:0.482973	validation_1-error:0.318182	validation_1-logloss:0.580618
# [215]	validation_0-error:0.177665	validation_0-logloss:0.482973	validation_1-error:0.318182	validation_1-logloss:0.580618
# [216]	validation_0-error:0.177665	validation_0-logloss:0.482973	validation_1-error:0.318182	validation_1-logloss:0.580618
# [217]	validation_0-error:0.177665	validation_0-logloss:0.482973	validation_1-error:0.318182	validation_1-logloss:0.580614
# [218]	validation_0-error:0.177665	validation_0-logloss:0.482972	validation_1-error:0.318182	validation_1-logloss:0.580634
# [219]	validation_0-error:0.177665	validation_0-logloss:0.482769	validation_1-error:0.318182	validation_1-logloss:0.580341
# [220]	validation_0-error:0.177665	validation_0-logloss:0.482769	validation_1-error:0.318182	validation_1-logloss:0.580338
# [221]	validation_0-error:0.177665	validation_0-logloss:0.482558	validation_1-error:0.318182	validation_1-logloss:0.580132
# [222]	validation_0-error:0.177665	validation_0-logloss:0.481753	validation_1-error:0.318182	validation_1-logloss:0.580038
# [223]	validation_0-error:0.177665	validation_0-logloss:0.481751	validation_1-error:0.318182	validation_1-logloss:0.580072
# [224]	validation_0-error:0.177665	validation_0-logloss:0.480985	validation_1-error:0.318182	validation_1-logloss:0.579954
# [225]	validation_0-error:0.177665	validation_0-logloss:0.480985	validation_1-error:0.318182	validation_1-logloss:0.579953
# [226]	validation_0-error:0.177665	validation_0-logloss:0.480982	validation_1-error:0.318182	validation_1-logloss:0.580011
# [227]	validation_0-error:0.177665	validation_0-logloss:0.480981	validation_1-error:0.318182	validation_1-logloss:0.580028
# [228]	validation_0-error:0.177665	validation_0-logloss:0.48098	validation_1-error:0.318182	validation_1-logloss:0.58006
# [229]	validation_0-error:0.177665	validation_0-logloss:0.480772	validation_1-error:0.318182	validation_1-logloss:0.579782
# [230]	validation_0-error:0.177665	validation_0-logloss:0.48077	validation_1-error:0.318182	validation_1-logloss:0.579821
# [231]	validation_0-error:0.177665	validation_0-logloss:0.480022	validation_1-error:0.318182	validation_1-logloss:0.579734
# [232]	validation_0-error:0.177665	validation_0-logloss:0.480021	validation_1-error:0.318182	validation_1-logloss:0.579749
# [233]	validation_0-error:0.177665	validation_0-logloss:0.480018	validation_1-error:0.318182	validation_1-logloss:0.579807
# [234]	validation_0-error:0.177665	validation_0-logloss:0.479822	validation_1-error:0.318182	validation_1-logloss:0.579623
# [235]	validation_0-error:0.177665	validation_0-logloss:0.479822	validation_1-error:0.318182	validation_1-logloss:0.579606
# [236]	validation_0-error:0.177665	validation_0-logloss:0.47982	validation_1-error:0.318182	validation_1-logloss:0.579659
# [237]	validation_0-error:0.177665	validation_0-logloss:0.47903	validation_1-error:0.318182	validation_1-logloss:0.579608
# [238]	validation_0-error:0.177665	validation_0-logloss:0.478264	validation_1-error:0.318182	validation_1-logloss:0.579479
# [239]	validation_0-error:0.177665	validation_0-logloss:0.478264	validation_1-error:0.318182	validation_1-logloss:0.579473
# [240]	validation_0-error:0.177665	validation_0-logloss:0.477502	validation_1-error:0.318182	validation_1-logloss:0.579353
# [241]	validation_0-error:0.177665	validation_0-logloss:0.476804	validation_1-error:0.318182	validation_1-logloss:0.57927
# [242]	validation_0-error:0.177665	validation_0-logloss:0.476031	validation_1-error:0.318182	validation_1-logloss:0.579156
# [243]	validation_0-error:0.177665	validation_0-logloss:0.475346	validation_1-error:0.318182	validation_1-logloss:0.579141
# [244]	validation_0-error:0.177665	validation_0-logloss:0.475344	validation_1-error:0.318182	validation_1-logloss:0.579177
# [245]	validation_0-error:0.177665	validation_0-logloss:0.475343	validation_1-error:0.318182	validation_1-logloss:0.579204
# [246]	validation_0-error:0.177665	validation_0-logloss:0.475341	validation_1-error:0.318182	validation_1-logloss:0.579265
# [247]	validation_0-error:0.177665	validation_0-logloss:0.475341	validation_1-error:0.318182	validation_1-logloss:0.579254
# [248]	validation_0-error:0.177665	validation_0-logloss:0.475342	validation_1-error:0.318182	validation_1-logloss:0.579234
# [249]	validation_0-error:0.177665	validation_0-logloss:0.474579	validation_1-error:0.318182	validation_1-logloss:0.57913
# [250]	validation_0-error:0.177665	validation_0-logloss:0.473929	validation_1-error:0.318182	validation_1-logloss:0.579046
# [251]	validation_0-error:0.177665	validation_0-logloss:0.473302	validation_1-error:0.318182	validation_1-logloss:0.578991
# [252]	validation_0-error:0.177665	validation_0-logloss:0.473301	validation_1-error:0.318182	validation_1-logloss:0.57901
# [253]	validation_0-error:0.177665	validation_0-logloss:0.473299	validation_1-error:0.318182	validation_1-logloss:0.579055
# [254]	validation_0-error:0.177665	validation_0-logloss:0.473299	validation_1-error:0.318182	validation_1-logloss:0.579065
# [255]	validation_0-error:0.177665	validation_0-logloss:0.473298	validation_1-error:0.318182	validation_1-logloss:0.579102
# [256]	validation_0-error:0.177665	validation_0-logloss:0.473297	validation_1-error:0.318182	validation_1-logloss:0.57912
# [257]	validation_0-error:0.177665	validation_0-logloss:0.473297	validation_1-error:0.318182	validation_1-logloss:0.579115
# [258]	validation_0-error:0.177665	validation_0-logloss:0.473296	validation_1-error:0.318182	validation_1-logloss:0.57916
# [259]	validation_0-error:0.177665	validation_0-logloss:0.472661	validation_1-error:0.318182	validation_1-logloss:0.579046
# [260]	validation_0-error:0.177665	validation_0-logloss:0.472661	validation_1-error:0.318182	validation_1-logloss:0.579043
# [261]	validation_0-error:0.177665	validation_0-logloss:0.472661	validation_1-error:0.318182	validation_1-logloss:0.579052
# Stopping. Best iteration:
# [251]	validation_0-error:0.177665	validation_0-logloss:0.473302	validation_1-error:0.318182	validation_1-logloss:0.578991
#
# Accuracy: 0.6818181818181818
# F1 score: 0.6037735849056604
# Recall: 0.47058823529411764
# Precision: 0.8421052631578947
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.91      0.73        32
#            1       0.84      0.47      0.60        34
#
#    micro avg       0.68      0.68      0.68        66
#    macro avg       0.73      0.69      0.67        66
# weighted avg       0.73      0.68      0.67        66
#
#
#  confussion matrix:
#  [[29  3]
#  [18 16]]

# %% [markdown]
# ### Display the Feature Importance for the modalities && Print weights given to each modality by the XGBClassifier

# %%
from matplotlib import pyplot
from xgboost import plot_importance
# feature importance
print(model.feature_importances_)
plot_importance(model)
pyplot.show()
# Out:
# [0.57697785 0.21712941 0.20589271]

# %% [markdown]
# ### RandomForestClassifier is used to vote for the feature Importance

# %%
from sklearn.ensemble import RandomForestClassifier
y_pred_a_test = model_a.predict(X_test_a)
y_pred_m_test = model_m.predict(X_test_m)
y_pred_g_test = model_g.predict(X_test_g)
y_pred_a_train = model_a.predict(X_train_a)
y_pred_m_train = model_m.predict(X_train_m)
y_pred_g_train = model_g.predict(X_train_g)
dfObj1 = pd.DataFrame(y_pred_a_train,columns = ['Audio'] )
dfObj2=pd.DataFrame(y_pred_m_train,columns = ['Mexp']) 
dfObj3=pd.DataFrame(y_pred_g_train,columns = ['Gaze'])
dfObj4 = pd.DataFrame(y_pred_a_test,columns = ['Audio']) 
dfObj5=pd.DataFrame(y_pred_m_test,columns = ['Mexp']) 
dfObj6=pd.DataFrame(y_pred_g_test,columns = ['Gaze'])
df_train_data = pd.concat([dfObj1, dfObj2, dfObj3], axis=1)
df_test_data = pd.concat([dfObj4, dfObj5, dfObj6], axis=1)
if(y_test_m==y_test_a):
    if(y_test_a==y_test_g):
        y_test=y_test_a
if(y_train_m==y_train_a):
    if(y_train_a==y_train_g):
        y_train=y_train_a
model_randomforest = RandomForestClassifier(max_depth=2, random_state=0)
model_randomforest.fit(df_train_data, y_train)
y_pred=model_randomforest.predict(df_test_data)
final_pred=[round(value) for value in y_pred]
print ('Accuracy:', accuracy_score(y_test, final_pred))
print ('F1 score:', f1_score(y_test, final_pred))
print ('Recall:', recall_score(y_test, final_pred))
print ('Precision:', precision_score(y_test, final_pred))
print ('\n clasification report:\n', classification_report(y_test,final_pred))
print ('\n confussion matrix:\n',confusion_matrix(y_test, final_pred))
# Out:
# Accuracy: 0.6818181818181818
# F1 score: 0.6037735849056604
# Recall: 0.47058823529411764
# Precision: 0.8421052631578947
#
#  clasification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.91      0.73        32
#            1       0.84      0.47      0.60        34
#
#    micro avg       0.68      0.68      0.68        66
#    macro avg       0.73      0.69      0.67        66
# weighted avg       0.73      0.68      0.67        66
#
#
#  confussion matrix:
#  [[29  3]
#  [18 16]]
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# ### Print weights given to each modality by the RandomForestClassifier

# %%
print(model_randomforest.feature_importances_)
# Out:
# [0.49291383 0.35272099 0.15436517]

# %% [markdown]
# ### Feature Importance obtained from RandomForestClassifier is plotted

# %%
features = ['Audio','Mexp','Gaze']
importances = model_randomforest.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
